# %% [markdown]
# # Отчет о создании и обучении на датасете Fashion MNIST модели CNN (гипотеза 6, реализация 2)

# %% [markdown]
# ## Содержание
#
# - Список терминов, специфичных для темы отчета
# - Введение
# - 1 Создание и обучение модели
#  - 1.1 Загрузка датасета
#  - 1.2 Создание модели
#  - 1.3 Обучение модели
#  - 1.4 Сохранение модели на диск
# - 2 Рекомендации по дальнейшему улучшению/развитию модели
# - Ссылки

# %% [markdown]
# ## Список терминов, специфичных для темы отчета
#
# См. раздел "Машинное обучение" документа "Словарь терминов, специфичных для выполняемых работ и изучаемых материалов в период с 25 сентября 2020 г. по 25 ноября 2020 г.".

# %% [markdown]
# ## Введение

# %% [markdown]
# В настоящем отчете приведен код, соответствующий созданию и обучению модели CNN на датасете Fashion MNIST, а также рекомендации по дальнейшему улучшению/развитию модели. Используемый язык программирования – Python. Для создания и обучения модели используются библиотеки MXNet и Gluon.

# %% [markdown]
# ## 1 Создание и обучение модели

# %% [markdown]
# Импортирование необходимых модулей и функций:

# %%
import mxnet as mx
from mxnet.optimizer import Adam
from mxnet import gluon, autograd
from mxnet.gluon import nn
from mxnet.gluon.data.vision import datasets, transforms

# %% [markdown]
# Установка вычислительного контекста (для использования при обучении видеокарты, если это возможно):

# %%
ctx = [mx.gpu() if mx.test_utils.list_gpus() else mx.cpu()]
print('context:', ctx)
# Out:
# context: [gpu(0)]

# %% [markdown]
# ### 1.1 Загрузка датасета

# %% [markdown]
# Загрузка датасета и установка размера батча равным 128:

# %%
batch_size = 128

mnist_train = datasets.FashionMNIST(train=True)
transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.13, 0.31)])
mnist_train = mnist_train.transform_first(transformer)
train_data = gluon.data.DataLoader(
    mnist_train, batch_size=batch_size, shuffle=True, num_workers=4)

mnist_valid = gluon.data.vision.FashionMNIST(train=False)
val_data = gluon.data.DataLoader(
    mnist_valid.transform_first(transformer),
    batch_size=batch_size, num_workers=4)

# %% [markdown]
# ### 1.2 Создание модели

# %% [markdown]
# Создание модели, состоящей из 4 слоев:
# 1. Сверточный слой с параметрами:
# 	- Количество каналов: 8
# 	- Размер ядра свертки: 4х4
# 	- Функция активации: гиперболический тангенс
# 2. Слой пулинга с параметрами:
# 	- Размер ядра пулинга: 2х2
# 	- Шаг: 2
# 3. Полносвязный слой с параметрами:
# 	- Количество нейронов: 16
# 	- Функция активации: гиперболический тангенс
# 4. Полносвязный слой с параметрами:
# 	- Количество нейронов: 10
# 	- Функция активации: гиперболический тангенс

# %%
net = nn.HybridSequential()
with net.name_scope():
    net.add(nn.Conv2D   (channels=8, kernel_size=4, activation='tanh'))
    net.add(nn.MaxPool2D(pool_size=2, strides=2))
    net.add(nn.Dense    (16, activation='tanh'))
    net.add(nn.Dense    (10, activation='tanh'))
net.hybridize()

# %% [markdown]
# ### 1.3 Обучение модели

# %% [markdown]
# Для инициализации сети используется метод Завьера (Xavier). В качестве функции потерь используется SCE (Softmax Cross-Entropy loss). В качестве оптимизатора используется Adam (Adaptive Moment Estimation – метод Адаптивной Оценки Моментов). Обучение производится на протижение **200** эпох.

# %%
epochsForTraining = 200
#                   ^^^--- 100 -> 200
validationAccToTrain = 0.90

def test(ctx):
    metric = mx.metric.Accuracy()
    for data, label in val_data:
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        output = net(data)
        metric.update([label], [output])

    return metric.get()

def train(net, ctx):
    # Collect all parameters from net and its children, then initialize them.
    net.initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
    # Trainer is for updating parameters with gradient.
    trainer = gluon.Trainer(net.collect_params(), Adam())
    metric = mx.metric.Accuracy()
    loss = gluon.loss.SoftmaxCrossEntropyLoss()

    maxValidationAcc = 0
    for i in range(epochsForTraining):
        # reset data iterator and metric at begining of epoch.
        metric.reset()
        for j, (data, label) in enumerate(train_data):
            # Copy data to ctx if necessary
            data = data.as_in_context(ctx)
            label = label.as_in_context(ctx)
            # Start recording computation graph with record() section.
            # Recorded graphs can then be differentiated with backward.
            with autograd.record():
                output = net(data)
                L = loss(output, label)
                L.backward()
            # take a gradient step with batch_size equal to data.shape[0]
            trainer.step(data.shape[0])
            # update metric at last.
            metric.update([label], [output])

        name, acc = metric.get()
        name, validationAcc = test(ctx)
        epoch = i + 1
        print('epoch', ('{:2.0f}:').format(epoch), '\t', "{:.2f}%".format(acc * 100), '- train set accuracy'
              '\n\t\t', "{:.2f}%".format(validationAcc * 100), '- validation set accuracy')
        if validationAcc > maxValidationAcc:
            maxValidationAcc = validationAcc
            if validationAcc >= validationAccToTrain:
                net.export('exported/200/fashion_mnist', epoch=epoch)
                print('saved epoch', epoch)
        print()
    print('Best result: {:.2f}%'.format(maxValidationAcc * 100))

# %%
train(net, ctx[0])
# Out:
# epoch  1: 	 77.33% - train set accuracy
# 		 83.58% - validation set accuracy
#
# epoch  2: 	 84.34% - train set accuracy
# 		 85.36% - validation set accuracy
#
# epoch  3: 	 85.93% - train set accuracy
# 		 86.68% - validation set accuracy
#
# epoch  4: 	 86.76% - train set accuracy
# 		 87.14% - validation set accuracy
#
# epoch  5: 	 87.37% - train set accuracy
# 		 86.83% - validation set accuracy
#
# epoch  6: 	 87.70% - train set accuracy
# 		 87.69% - validation set accuracy
#
# epoch  7: 	 88.17% - train set accuracy
# 		 87.99% - validation set accuracy
#
# epoch  8: 	 88.40% - train set accuracy
# 		 88.25% - validation set accuracy
#
# epoch  9: 	 88.62% - train set accuracy
# 		 88.33% - validation set accuracy
#
# epoch 10: 	 88.87% - train set accuracy
# 		 88.48% - validation set accuracy
#
# epoch 11: 	 89.04% - train set accuracy
# 		 88.16% - validation set accuracy
#
# epoch 12: 	 89.15% - train set accuracy
# 		 88.46% - validation set accuracy
#
# epoch 13: 	 89.22% - train set accuracy
# 		 88.74% - validation set accuracy
#
# epoch 14: 	 89.43% - train set accuracy
# 		 88.60% - validation set accuracy
#
# epoch 15: 	 89.54% - train set accuracy
# 		 88.54% - validation set accuracy
#
# epoch 16: 	 89.66% - train set accuracy
# 		 88.83% - validation set accuracy
#
# epoch 17: 	 89.90% - train set accuracy
# 		 88.55% - validation set accuracy
#
# epoch 18: 	 89.85% - train set accuracy
# 		 89.08% - validation set accuracy
#
# epoch 19: 	 90.05% - train set accuracy
# 		 89.10% - validation set accuracy
#
# epoch 20: 	 90.00% - train set accuracy
# 		 88.95% - validation set accuracy
#
# epoch 21: 	 90.22% - train set accuracy
# 		 88.80% - validation set accuracy
#
# epoch 22: 	 90.29% - train set accuracy
# 		 89.16% - validation set accuracy
#
# epoch 23: 	 90.39% - train set accuracy
# 		 89.08% - validation set accuracy
#
# epoch 24: 	 90.53% - train set accuracy
# 		 88.88% - validation set accuracy
#
# epoch 25: 	 90.46% - train set accuracy
# 		 89.03% - validation set accuracy
#
# epoch 26: 	 90.60% - train set accuracy
# 		 89.37% - validation set accuracy
#
# epoch 27: 	 90.71% - train set accuracy
# 		 89.29% - validation set accuracy
#
# epoch 28: 	 90.80% - train set accuracy
# 		 89.38% - validation set accuracy
#
# epoch 29: 	 90.92% - train set accuracy
# 		 88.92% - validation set accuracy
#
# epoch 30: 	 90.84% - train set accuracy
# 		 89.15% - validation set accuracy
#
# epoch 31: 	 90.85% - train set accuracy
# 		 89.20% - validation set accuracy
#
# epoch 32: 	 90.96% - train set accuracy
# 		 89.35% - validation set accuracy
#
# epoch 33: 	 91.19% - train set accuracy
# 		 89.48% - validation set accuracy
#
# epoch 34: 	 91.07% - train set accuracy
# 		 89.11% - validation set accuracy
#
# epoch 35: 	 91.25% - train set accuracy
# 		 89.23% - validation set accuracy
#
# epoch 36: 	 91.28% - train set accuracy
# 		 89.31% - validation set accuracy
#
# epoch 37: 	 91.37% - train set accuracy
# 		 89.35% - validation set accuracy
#
# epoch 38: 	 91.38% - train set accuracy
# 		 89.54% - validation set accuracy
#
# epoch 39: 	 91.34% - train set accuracy
# 		 89.72% - validation set accuracy
#
# epoch 40: 	 91.42% - train set accuracy
# 		 89.10% - validation set accuracy
#
# epoch 41: 	 91.62% - train set accuracy
# 		 89.50% - validation set accuracy
#
# epoch 42: 	 91.61% - train set accuracy
# 		 89.68% - validation set accuracy
#
# epoch 43: 	 91.66% - train set accuracy
# 		 89.40% - validation set accuracy
#
# epoch 44: 	 91.60% - train set accuracy
# 		 89.40% - validation set accuracy
#
# epoch 45: 	 91.64% - train set accuracy
# 		 89.57% - validation set accuracy
#
# epoch 46: 	 91.73% - train set accuracy
# 		 88.89% - validation set accuracy
#
# epoch 47: 	 91.80% - train set accuracy
# 		 89.59% - validation set accuracy
#
# epoch 48: 	 91.77% - train set accuracy
# 		 89.25% - validation set accuracy
#
# epoch 49: 	 91.78% - train set accuracy
# 		 89.56% - validation set accuracy
#
# epoch 50: 	 91.88% - train set accuracy
# 		 89.67% - validation set accuracy
#
# epoch 51: 	 91.88% - train set accuracy
# 		 89.73% - validation set accuracy
#
# epoch 52: 	 92.01% - train set accuracy
# 		 89.38% - validation set accuracy
#
# epoch 53: 	 92.06% - train set accuracy
# 		 89.66% - validation set accuracy
#
# epoch 54: 	 91.97% - train set accuracy
# 		 89.09% - validation set accuracy
#
# epoch 55: 	 92.07% - train set accuracy
# 		 89.78% - validation set accuracy
#
# epoch 56: 	 92.06% - train set accuracy
# 		 89.38% - validation set accuracy
#
# epoch 57: 	 92.14% - train set accuracy
# 		 89.60% - validation set accuracy
#
# epoch 58: 	 92.20% - train set accuracy
# 		 89.55% - validation set accuracy
#
# epoch 59: 	 92.19% - train set accuracy
# 		 89.44% - validation set accuracy
#
# epoch 60: 	 92.16% - train set accuracy
# 		 89.51% - validation set accuracy
#
# epoch 61: 	 92.27% - train set accuracy
# 		 89.59% - validation set accuracy
#
# epoch 62: 	 92.31% - train set accuracy
# 		 89.52% - validation set accuracy
#
# epoch 63: 	 92.33% - train set accuracy
# 		 89.40% - validation set accuracy
#
# epoch 64: 	 92.40% - train set accuracy
# 		 89.44% - validation set accuracy
#
# epoch 65: 	 92.31% - train set accuracy
# 		 89.38% - validation set accuracy
#
# epoch 66: 	 92.37% - train set accuracy
# 		 89.64% - validation set accuracy
#
# epoch 67: 	 92.44% - train set accuracy
# 		 89.52% - validation set accuracy
#
# epoch 68: 	 92.40% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 69: 	 92.43% - train set accuracy
# 		 89.55% - validation set accuracy
#
# epoch 70: 	 92.52% - train set accuracy
# 		 89.25% - validation set accuracy
#
# epoch 71: 	 92.48% - train set accuracy
# 		 89.53% - validation set accuracy
#
# epoch 72: 	 92.55% - train set accuracy
# 		 89.30% - validation set accuracy
#
# epoch 73: 	 92.56% - train set accuracy
# 		 89.37% - validation set accuracy
#
# epoch 74: 	 92.54% - train set accuracy
# 		 89.59% - validation set accuracy
#
# epoch 75: 	 92.58% - train set accuracy
# 		 89.50% - validation set accuracy
#
# epoch 76: 	 92.55% - train set accuracy
# 		 89.46% - validation set accuracy
#
# epoch 77: 	 92.50% - train set accuracy
# 		 89.40% - validation set accuracy
#
# epoch 78: 	 92.58% - train set accuracy
# 		 89.53% - validation set accuracy
#
# epoch 79: 	 92.68% - train set accuracy
# 		 89.17% - validation set accuracy
#
# epoch 80: 	 92.62% - train set accuracy
# 		 89.55% - validation set accuracy
#
# epoch 81: 	 92.70% - train set accuracy
# 		 89.58% - validation set accuracy
#
# epoch 82: 	 92.74% - train set accuracy
# 		 89.61% - validation set accuracy
#
# epoch 83: 	 92.74% - train set accuracy
# 		 89.15% - validation set accuracy
#
# epoch 84: 	 92.62% - train set accuracy
# 		 89.08% - validation set accuracy
#
# epoch 85: 	 92.75% - train set accuracy
# 		 89.24% - validation set accuracy
#
# epoch 86: 	 92.78% - train set accuracy
# 		 89.40% - validation set accuracy
#
# epoch 87: 	 92.83% - train set accuracy
# 		 89.28% - validation set accuracy
#
# epoch 88: 	 92.87% - train set accuracy
# 		 89.38% - validation set accuracy
#
# epoch 89: 	 92.84% - train set accuracy
# 		 89.49% - validation set accuracy
#
# epoch 90: 	 92.81% - train set accuracy
# 		 89.60% - validation set accuracy
#
# epoch 91: 	 92.83% - train set accuracy
# 		 89.44% - validation set accuracy
#
# epoch 92: 	 92.83% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 93: 	 92.79% - train set accuracy
# 		 89.05% - validation set accuracy
#
# epoch 94: 	 92.81% - train set accuracy
# 		 89.38% - validation set accuracy
#
# epoch 95: 	 92.84% - train set accuracy
# 		 89.27% - validation set accuracy
#
# epoch 96: 	 92.94% - train set accuracy
# 		 89.48% - validation set accuracy
#
# epoch 97: 	 92.97% - train set accuracy
# 		 88.82% - validation set accuracy
#
# epoch 98: 	 92.87% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 99: 	 92.95% - train set accuracy
# 		 89.35% - validation set accuracy
#
# epoch 100: 	 92.97% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 101: 	 92.98% - train set accuracy
# 		 89.43% - validation set accuracy
#
# epoch 102: 	 92.97% - train set accuracy
# 		 89.46% - validation set accuracy
#
# epoch 103: 	 93.01% - train set accuracy
# 		 89.22% - validation set accuracy
#
# epoch 104: 	 93.04% - train set accuracy
# 		 89.49% - validation set accuracy
#
# epoch 105: 	 93.03% - train set accuracy
# 		 89.38% - validation set accuracy
#
# epoch 106: 	 93.06% - train set accuracy
# 		 89.26% - validation set accuracy
#
# epoch 107: 	 93.02% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 108: 	 93.09% - train set accuracy
# 		 89.42% - validation set accuracy
#
# epoch 109: 	 93.01% - train set accuracy
# 		 89.39% - validation set accuracy
#
# epoch 110: 	 93.14% - train set accuracy
# 		 89.48% - validation set accuracy
#
# epoch 111: 	 93.08% - train set accuracy
# 		 89.25% - validation set accuracy
#
# epoch 112: 	 93.19% - train set accuracy
# 		 89.21% - validation set accuracy
#
# epoch 113: 	 93.07% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 114: 	 93.07% - train set accuracy
# 		 89.48% - validation set accuracy
#
# epoch 115: 	 93.08% - train set accuracy
# 		 89.63% - validation set accuracy
#
# epoch 116: 	 93.21% - train set accuracy
# 		 89.40% - validation set accuracy
#
# epoch 117: 	 93.11% - train set accuracy
# 		 89.02% - validation set accuracy
#
# epoch 118: 	 93.09% - train set accuracy
# 		 89.22% - validation set accuracy
#
# epoch 119: 	 93.13% - train set accuracy
# 		 89.42% - validation set accuracy
#
# epoch 120: 	 93.22% - train set accuracy
# 		 89.19% - validation set accuracy
#
# epoch 121: 	 93.21% - train set accuracy
# 		 89.51% - validation set accuracy
#
# epoch 122: 	 93.07% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 123: 	 93.21% - train set accuracy
# 		 89.03% - validation set accuracy
#
# epoch 124: 	 93.21% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 125: 	 93.11% - train set accuracy
# 		 89.41% - validation set accuracy
#
# epoch 126: 	 93.34% - train set accuracy
# 		 89.14% - validation set accuracy
#
# epoch 127: 	 93.19% - train set accuracy
# 		 89.63% - validation set accuracy
#
# epoch 128: 	 93.27% - train set accuracy
# 		 89.33% - validation set accuracy
#
# epoch 129: 	 93.21% - train set accuracy
# 		 89.53% - validation set accuracy
#
# epoch 130: 	 93.31% - train set accuracy
# 		 89.16% - validation set accuracy
#
# epoch 131: 	 93.27% - train set accuracy
# 		 89.32% - validation set accuracy
#
# epoch 132: 	 93.32% - train set accuracy
# 		 89.32% - validation set accuracy
#
# epoch 133: 	 93.29% - train set accuracy
# 		 89.27% - validation set accuracy
#
# epoch 134: 	 93.29% - train set accuracy
# 		 88.81% - validation set accuracy
#
# epoch 135: 	 93.36% - train set accuracy
# 		 89.23% - validation set accuracy
#
# epoch 136: 	 93.28% - train set accuracy
# 		 89.46% - validation set accuracy
#
# epoch 137: 	 93.39% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 138: 	 93.22% - train set accuracy
# 		 89.49% - validation set accuracy
#
# epoch 139: 	 93.38% - train set accuracy
# 		 88.97% - validation set accuracy
#
# epoch 140: 	 93.33% - train set accuracy
# 		 89.14% - validation set accuracy
#
# epoch 141: 	 93.39% - train set accuracy
# 		 89.24% - validation set accuracy
#
# epoch 142: 	 93.37% - train set accuracy
# 		 89.36% - validation set accuracy
#
# epoch 143: 	 93.32% - train set accuracy
# 		 89.13% - validation set accuracy
#
# epoch 144: 	 93.39% - train set accuracy
# 		 89.30% - validation set accuracy
#
# epoch 145: 	 93.46% - train set accuracy
# 		 89.33% - validation set accuracy
#
# epoch 146: 	 93.44% - train set accuracy
# 		 89.21% - validation set accuracy
#
# epoch 147: 	 93.39% - train set accuracy
# 		 89.35% - validation set accuracy
#
# epoch 148: 	 93.38% - train set accuracy
# 		 89.20% - validation set accuracy
#
# epoch 149: 	 93.35% - train set accuracy
# 		 89.40% - validation set accuracy
#
# epoch 150: 	 93.45% - train set accuracy
# 		 89.34% - validation set accuracy
#
# epoch 151: 	 93.49% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 152: 	 93.48% - train set accuracy
# 		 88.98% - validation set accuracy
#
# epoch 153: 	 93.36% - train set accuracy
# 		 88.90% - validation set accuracy
#
# epoch 154: 	 93.47% - train set accuracy
# 		 89.20% - validation set accuracy
#
# epoch 155: 	 93.42% - train set accuracy
# 		 89.26% - validation set accuracy
#
# epoch 156: 	 93.39% - train set accuracy
# 		 89.41% - validation set accuracy
#
# epoch 157: 	 93.50% - train set accuracy
# 		 89.32% - validation set accuracy
#
# epoch 158: 	 93.45% - train set accuracy
# 		 89.03% - validation set accuracy
#
# epoch 159: 	 93.55% - train set accuracy
# 		 89.40% - validation set accuracy
#
# epoch 160: 	 93.60% - train set accuracy
# 		 89.19% - validation set accuracy
#
# epoch 161: 	 93.54% - train set accuracy
# 		 89.33% - validation set accuracy
#
# epoch 162: 	 93.60% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 163: 	 93.48% - train set accuracy
# 		 89.12% - validation set accuracy
#
# epoch 164: 	 93.66% - train set accuracy
# 		 89.13% - validation set accuracy
#
# epoch 165: 	 93.57% - train set accuracy
# 		 89.16% - validation set accuracy
#
# epoch 166: 	 93.68% - train set accuracy
# 		 89.17% - validation set accuracy
#
# epoch 167: 	 93.46% - train set accuracy
# 		 89.04% - validation set accuracy
#
# epoch 168: 	 93.56% - train set accuracy
# 		 89.14% - validation set accuracy
#
# epoch 169: 	 93.58% - train set accuracy
# 		 89.28% - validation set accuracy
#
# epoch 170: 	 93.68% - train set accuracy
# 		 89.34% - validation set accuracy
#
# epoch 171: 	 93.57% - train set accuracy
# 		 89.14% - validation set accuracy
#
# epoch 172: 	 93.60% - train set accuracy
# 		 88.98% - validation set accuracy
#
# epoch 173: 	 93.55% - train set accuracy
# 		 89.07% - validation set accuracy
#
# epoch 174: 	 93.64% - train set accuracy
# 		 88.97% - validation set accuracy
#
# epoch 175: 	 93.61% - train set accuracy
# 		 89.07% - validation set accuracy
#
# epoch 176: 	 93.55% - train set accuracy
# 		 89.19% - validation set accuracy
#
# epoch 177: 	 93.61% - train set accuracy
# 		 88.89% - validation set accuracy
#
# epoch 178: 	 93.57% - train set accuracy
# 		 89.30% - validation set accuracy
#
# epoch 179: 	 93.58% - train set accuracy
# 		 89.04% - validation set accuracy
#
# epoch 180: 	 93.65% - train set accuracy
# 		 89.28% - validation set accuracy
#
# epoch 181: 	 93.70% - train set accuracy
# 		 89.22% - validation set accuracy
#
# epoch 182: 	 93.67% - train set accuracy
# 		 89.26% - validation set accuracy
#
# epoch 183: 	 93.64% - train set accuracy
# 		 88.99% - validation set accuracy
#
# epoch 184: 	 93.71% - train set accuracy
# 		 89.06% - validation set accuracy
#
# epoch 185: 	 93.61% - train set accuracy
# 		 89.16% - validation set accuracy
#
# epoch 186: 	 93.73% - train set accuracy
# 		 89.00% - validation set accuracy
#
# epoch 187: 	 93.72% - train set accuracy
# 		 89.22% - validation set accuracy
#
# epoch 188: 	 93.59% - train set accuracy
# 		 89.21% - validation set accuracy
#
# epoch 189: 	 93.72% - train set accuracy
# 		 89.19% - validation set accuracy
#
# epoch 190: 	 93.81% - train set accuracy
# 		 89.16% - validation set accuracy
#
# epoch 191: 	 93.75% - train set accuracy
# 		 88.95% - validation set accuracy
#
# epoch 192: 	 93.72% - train set accuracy
# 		 88.80% - validation set accuracy
#
# epoch 193: 	 93.67% - train set accuracy
# 		 88.81% - validation set accuracy
#
# epoch 194: 	 93.72% - train set accuracy
# 		 89.21% - validation set accuracy
#
# epoch 195: 	 93.80% - train set accuracy
# 		 89.09% - validation set accuracy
#
# epoch 196: 	 93.81% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 197: 	 93.77% - train set accuracy
# 		 89.04% - validation set accuracy
#
# epoch 198: 	 93.77% - train set accuracy
# 		 89.23% - validation set accuracy
#
# epoch 199: 	 93.70% - train set accuracy
# 		 89.17% - validation set accuracy
#
# epoch 200: 	 93.82% - train set accuracy
# 		 88.85% - validation set accuracy
#
# Best result: 89.78%

# %% [markdown]
# Максимальная достигнутая точность на проверочной части датасета составляет **89.78%**

# %% [markdown]
# ### 1.4 Сохранение модели на диск

# %% [markdown]
# Обучение модели выполняется посредством функции `train` (см. раздел 1.3). Функция `train` использует глобальные переменные `validationAccToTrain` и `epochsForTraining`. Значение глобальной переменной `validationAccToTrain` соответствует точности (accuracy) на проверочной части датасета, при достижении которой и одновременно максимальной точности в ходе обучения, необходимо сохранить архитектуру и параметры модели на диск. Сохранение модели на диск выполняется посредством функции `net.export`, при этом создаются/перезаписываются два файла: **fashion-mnist-symbol.json**, содержащий информацию, определяющую архитектуру модели, и **fashion-mnist-<номер эпохи>.params**, содержащий параметры модели, полученные в ходе обучения и соответствующие эпохе <номер эпохи>. Значение глобальной переменной `epochsForTraining` соответствует количеству эпох, в течение которых необходимо проводить обучение.

# %% [markdown]
# ## Ссылки

# %% [markdown]
# 1. Официальный сайт mxnet: https://mxnet.apache.org/
