# %% [markdown]
# # Отчет о создании и обучении на датасете Fashion MNIST модели CNN (гипотеза 1, реализация 3)

# %% [markdown]
# ## Содержание
#
# - Список терминов, специфичных для темы отчета
# - Введение
# - 1 Создание и обучение модели
#  - 1.1 Загрузка датасета
#  - 1.2 Создание модели
#  - 1.3 Обучение модели
#  - 1.4 Сохранение модели на диск
# - 2 Рекомендации по дальнейшему улучшению/развитию модели
# - Ссылки

# %% [markdown]
# ## Список терминов, специфичных для темы отчета
#
# См. раздел "Машинное обучение" документа "Словарь терминов, специфичных для выполняемых работ и изучаемых материалов в период с 25 сентября 2020 г. по 25 ноября 2020 г.".

# %% [markdown]
# ## Введение

# %% [markdown]
# В настоящем отчете приведен код, соответствующий созданию и обучению модели CNN на датасете Fashion MNIST, а также рекомендации по дальнейшему улучшению/развитию модели. Используемый язык программирования – Python. Для создания и обучения модели используются библиотеки MXNet и Gluon.

# %% [markdown]
# ## 1 Создание и обучение модели

# %% [markdown]
# Импортирование необходимых модулей и функций:

# %%
import mxnet as mx
from mxnet.optimizer import Adam
from mxnet import gluon, autograd
from mxnet.gluon import nn
from mxnet.gluon.data.vision import datasets, transforms

# %% [markdown]
# Установка вычислительного контекста (для использования при обучении видеокарты, если это возможно):

# %%
ctx = [mx.gpu() if mx.test_utils.list_gpus() else mx.cpu()]
print('context:', ctx)
# Out:
# context: [gpu(0)]

# %% [markdown]
# ### 1.1 Загрузка датасета

# %% [markdown]
# Загрузка датасета и установка размера батча равным 128:

# %%
batch_size = 128

mnist_train = datasets.FashionMNIST(train=True)
transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.13, 0.31)])
mnist_train = mnist_train.transform_first(transformer)
train_data = gluon.data.DataLoader(
    mnist_train, batch_size=batch_size, shuffle=True, num_workers=4)

mnist_valid = gluon.data.vision.FashionMNIST(train=False)
val_data = gluon.data.DataLoader(
    mnist_valid.transform_first(transformer),
    batch_size=batch_size, num_workers=4)

# %% [markdown]
# ### 1.2 Создание модели

# %% [markdown]
# Создание модели, состоящей из 4 слоев:
# 1. Сверточный слой с параметрами:
# 	- Количество каналов: 8
# 	- Размер ядра свертки: 4х4
# 	- Функция активации: гиперболический тангенс
# 2. Слой пулинга с параметрами:
# 	- Размер ядра пулинга: 2х2
# 	- Шаг: 2
# 3. Полносвязный слой с параметрами:
# 	- Количество нейронов: 16
# 	- Функция активации: гиперболический тангенс
# 4. Полносвязный слой с параметрами:
# 	- Количество нейронов: 10
# 	- Функция активации: гиперболический тангенс

# %%
net = nn.HybridSequential()
with net.name_scope():
    net.add(nn.Conv2D   (channels=8, kernel_size=4, activation='tanh'))
    net.add(nn.MaxPool2D(pool_size=2, strides=2))
    net.add(nn.Dense    (128, activation='tanh'))
    #                    ^^--- 16 -> 128
    net.add(nn.Dense    (10, activation='tanh'))
net.hybridize()

# %% [markdown]
# ### 1.3 Обучение модели

# %% [markdown]
# Для инициализации сети используется метод Завьера (Xavier). В качестве функции потерь используется SCE (Softmax Cross-Entropy loss). В качестве оптимизатора используется Adam (Adaptive Moment Estimation – метод Адаптивной Оценки Моментов). Обучение производится на протижение 100 эпох.

# %%
epochsForTraining = 100
validationAccToTrain = 0.90

def test(ctx):
    metric = mx.metric.Accuracy()
    for data, label in val_data:
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        output = net(data)
        metric.update([label], [output])

    return metric.get()

def train(net, ctx):
    # Collect all parameters from net and its children, then initialize them.
    net.initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
    # Trainer is for updating parameters with gradient.
    trainer = gluon.Trainer(net.collect_params(), Adam())
    metric = mx.metric.Accuracy()
    loss = gluon.loss.SoftmaxCrossEntropyLoss()

    maxValidationAcc = 0
    for i in range(epochsForTraining):
        # reset data iterator and metric at begining of epoch.
        metric.reset()
        for j, (data, label) in enumerate(train_data):
            # Copy data to ctx if necessary
            data = data.as_in_context(ctx)
            label = label.as_in_context(ctx)
            # Start recording computation graph with record() section.
            # Recorded graphs can then be differentiated with backward.
            with autograd.record():
                output = net(data)
                L = loss(output, label)
                L.backward()
            # take a gradient step with batch_size equal to data.shape[0]
            trainer.step(data.shape[0])
            # update metric at last.
            metric.update([label], [output])

        name, acc = metric.get()
        name, validationAcc = test(ctx)
        epoch = i + 1
        print('epoch', ('{:2.0f}:').format(epoch), '\t', "{:.2f}%".format(acc * 100), '- train set accuracy'
              '\n\t\t', "{:.2f}%".format(validationAcc * 100), '- validation set accuracy')
        if validationAcc > maxValidationAcc:
            maxValidationAcc = validationAcc
            if validationAcc >= validationAccToTrain:
                net.export('exported/128/fashion_mnist', epoch=epoch)
                print('saved epoch', epoch)
        print()
    print('Best result: {:.2f}%'.format(maxValidationAcc * 100))

# %%
train(net, ctx[0])
# Out:
# epoch  1: 	 79.70% - train set accuracy
# 		 85.46% - validation set accuracy
#
# epoch  2: 	 86.08% - train set accuracy
# 		 87.50% - validation set accuracy
#
# epoch  3: 	 87.76% - train set accuracy
# 		 87.19% - validation set accuracy
#
# epoch  4: 	 88.51% - train set accuracy
# 		 88.21% - validation set accuracy
#
# epoch  5: 	 89.19% - train set accuracy
# 		 89.14% - validation set accuracy
#
# epoch  6: 	 89.72% - train set accuracy
# 		 89.31% - validation set accuracy
#
# epoch  7: 	 90.14% - train set accuracy
# 		 89.48% - validation set accuracy
#
# epoch  8: 	 90.60% - train set accuracy
# 		 89.67% - validation set accuracy
#
# epoch  9: 	 90.79% - train set accuracy
# 		 90.22% - validation set accuracy
# saved epoch 9
#
# epoch 10: 	 91.26% - train set accuracy
# 		 90.37% - validation set accuracy
# saved epoch 10
#
# epoch 11: 	 91.69% - train set accuracy
# 		 90.06% - validation set accuracy
#
# epoch 12: 	 91.77% - train set accuracy
# 		 90.15% - validation set accuracy
#
# epoch 13: 	 92.10% - train set accuracy
# 		 90.14% - validation set accuracy
#
# epoch 14: 	 92.41% - train set accuracy
# 		 90.41% - validation set accuracy
# saved epoch 14
#
# epoch 15: 	 92.53% - train set accuracy
# 		 90.13% - validation set accuracy
#
# epoch 16: 	 92.72% - train set accuracy
# 		 90.57% - validation set accuracy
# saved epoch 16
#
# epoch 17: 	 93.00% - train set accuracy
# 		 90.56% - validation set accuracy
#
# epoch 18: 	 93.18% - train set accuracy
# 		 90.59% - validation set accuracy
# saved epoch 18
#
# epoch 19: 	 93.41% - train set accuracy
# 		 90.55% - validation set accuracy
#
# epoch 20: 	 93.58% - train set accuracy
# 		 90.71% - validation set accuracy
# saved epoch 20
#
# epoch 21: 	 93.68% - train set accuracy
# 		 90.60% - validation set accuracy
#
# epoch 22: 	 93.91% - train set accuracy
# 		 90.79% - validation set accuracy
# saved epoch 22
#
# epoch 23: 	 93.94% - train set accuracy
# 		 90.60% - validation set accuracy
#
# epoch 24: 	 94.23% - train set accuracy
# 		 90.83% - validation set accuracy
# saved epoch 24
#
# epoch 25: 	 94.27% - train set accuracy
# 		 90.77% - validation set accuracy
#
# epoch 26: 	 94.47% - train set accuracy
# 		 91.09% - validation set accuracy
# saved epoch 26
#
# epoch 27: 	 94.54% - train set accuracy
# 		 90.37% - validation set accuracy
#
# epoch 28: 	 94.77% - train set accuracy
# 		 90.72% - validation set accuracy
#
# epoch 29: 	 94.94% - train set accuracy
# 		 90.94% - validation set accuracy
#
# epoch 30: 	 95.01% - train set accuracy
# 		 90.74% - validation set accuracy
#
# epoch 31: 	 95.18% - train set accuracy
# 		 90.79% - validation set accuracy
#
# epoch 32: 	 95.28% - train set accuracy
# 		 91.03% - validation set accuracy
#
# epoch 33: 	 95.34% - train set accuracy
# 		 90.66% - validation set accuracy
#
# epoch 34: 	 95.50% - train set accuracy
# 		 90.78% - validation set accuracy
#
# epoch 35: 	 95.62% - train set accuracy
# 		 90.71% - validation set accuracy
#
# epoch 36: 	 95.53% - train set accuracy
# 		 91.22% - validation set accuracy
# saved epoch 36
#
# epoch 37: 	 95.70% - train set accuracy
# 		 90.87% - validation set accuracy
#
# epoch 38: 	 95.77% - train set accuracy
# 		 90.74% - validation set accuracy
#
# epoch 39: 	 95.99% - train set accuracy
# 		 91.03% - validation set accuracy
#
# epoch 40: 	 95.97% - train set accuracy
# 		 91.02% - validation set accuracy
#
# epoch 41: 	 96.09% - train set accuracy
# 		 90.89% - validation set accuracy
#
# epoch 42: 	 96.12% - train set accuracy
# 		 91.17% - validation set accuracy
#
# epoch 43: 	 96.27% - train set accuracy
# 		 91.07% - validation set accuracy
#
# epoch 44: 	 96.29% - train set accuracy
# 		 91.15% - validation set accuracy
#
# epoch 45: 	 96.38% - train set accuracy
# 		 91.01% - validation set accuracy
#
# epoch 46: 	 96.43% - train set accuracy
# 		 90.99% - validation set accuracy
#
# epoch 47: 	 96.55% - train set accuracy
# 		 91.07% - validation set accuracy
#
# epoch 48: 	 96.58% - train set accuracy
# 		 90.94% - validation set accuracy
#
# epoch 49: 	 96.66% - train set accuracy
# 		 91.10% - validation set accuracy
#
# epoch 50: 	 96.84% - train set accuracy
# 		 91.24% - validation set accuracy
# saved epoch 50
#
# epoch 51: 	 96.73% - train set accuracy
# 		 91.07% - validation set accuracy
#
# epoch 52: 	 96.83% - train set accuracy
# 		 90.94% - validation set accuracy
#
# epoch 53: 	 96.92% - train set accuracy
# 		 91.07% - validation set accuracy
#
# epoch 54: 	 97.01% - train set accuracy
# 		 91.05% - validation set accuracy
#
# epoch 55: 	 96.99% - train set accuracy
# 		 90.81% - validation set accuracy
#
# epoch 56: 	 97.08% - train set accuracy
# 		 91.14% - validation set accuracy
#
# epoch 57: 	 97.10% - train set accuracy
# 		 91.09% - validation set accuracy
#
# epoch 58: 	 97.23% - train set accuracy
# 		 90.93% - validation set accuracy
#
# epoch 59: 	 97.20% - train set accuracy
# 		 91.08% - validation set accuracy
#
# epoch 60: 	 97.25% - train set accuracy
# 		 91.08% - validation set accuracy
#
# epoch 61: 	 97.30% - train set accuracy
# 		 90.93% - validation set accuracy
#
# epoch 62: 	 97.20% - train set accuracy
# 		 91.25% - validation set accuracy
# saved epoch 62
#
# epoch 63: 	 97.51% - train set accuracy
# 		 91.10% - validation set accuracy
#
# epoch 64: 	 97.48% - train set accuracy
# 		 90.97% - validation set accuracy
#
# epoch 65: 	 97.52% - train set accuracy
# 		 91.03% - validation set accuracy
#
# epoch 66: 	 97.47% - train set accuracy
# 		 90.98% - validation set accuracy
#
# epoch 67: 	 97.54% - train set accuracy
# 		 90.87% - validation set accuracy
#
# epoch 68: 	 97.70% - train set accuracy
# 		 90.99% - validation set accuracy
#
# epoch 69: 	 97.64% - train set accuracy
# 		 90.70% - validation set accuracy
#
# epoch 70: 	 97.59% - train set accuracy
# 		 91.08% - validation set accuracy
#
# epoch 71: 	 97.80% - train set accuracy
# 		 91.12% - validation set accuracy
#
# epoch 72: 	 97.75% - train set accuracy
# 		 91.00% - validation set accuracy
#
# epoch 73: 	 97.66% - train set accuracy
# 		 91.00% - validation set accuracy
#
# epoch 74: 	 97.69% - train set accuracy
# 		 91.04% - validation set accuracy
#
# epoch 75: 	 97.89% - train set accuracy
# 		 91.21% - validation set accuracy
#
# epoch 76: 	 97.91% - train set accuracy
# 		 91.03% - validation set accuracy
#
# epoch 77: 	 97.80% - train set accuracy
# 		 90.92% - validation set accuracy
#
# epoch 78: 	 97.83% - train set accuracy
# 		 90.73% - validation set accuracy
#
# epoch 79: 	 97.83% - train set accuracy
# 		 91.06% - validation set accuracy
#
# epoch 80: 	 98.00% - train set accuracy
# 		 91.08% - validation set accuracy
#
# epoch 81: 	 97.83% - train set accuracy
# 		 90.75% - validation set accuracy
#
# epoch 82: 	 97.90% - train set accuracy
# 		 90.84% - validation set accuracy
#
# epoch 83: 	 97.93% - train set accuracy
# 		 90.88% - validation set accuracy
#
# epoch 84: 	 97.91% - train set accuracy
# 		 91.18% - validation set accuracy
#
# epoch 85: 	 98.12% - train set accuracy
# 		 90.92% - validation set accuracy
#
# epoch 86: 	 97.98% - train set accuracy
# 		 90.93% - validation set accuracy
#
# epoch 87: 	 98.07% - train set accuracy
# 		 90.94% - validation set accuracy
#
# epoch 88: 	 98.05% - train set accuracy
# 		 90.60% - validation set accuracy
#
# epoch 89: 	 98.00% - train set accuracy
# 		 90.82% - validation set accuracy
#
# epoch 90: 	 98.14% - train set accuracy
# 		 91.20% - validation set accuracy
#
# epoch 91: 	 98.13% - train set accuracy
# 		 90.88% - validation set accuracy
#
# epoch 92: 	 98.16% - train set accuracy
# 		 90.93% - validation set accuracy
#
# epoch 93: 	 98.22% - train set accuracy
# 		 90.92% - validation set accuracy
#
# epoch 94: 	 98.20% - train set accuracy
# 		 90.99% - validation set accuracy
#
# epoch 95: 	 98.03% - train set accuracy
# 		 90.86% - validation set accuracy
#
# epoch 96: 	 98.32% - train set accuracy
# 		 90.92% - validation set accuracy
#
# epoch 97: 	 98.28% - train set accuracy
# 		 90.76% - validation set accuracy
#
# epoch 98: 	 98.12% - train set accuracy
# 		 90.52% - validation set accuracy
#
# epoch 99: 	 98.26% - train set accuracy
# 		 91.02% - validation set accuracy
#
# epoch 100: 	 98.24% - train set accuracy
# 		 91.07% - validation set accuracy
#
# Best result: 91.25%

# %% [markdown]
# Максимальная достигнутая точность на проверочной части датасета составляет **91.25%**

# %% [markdown]
# ### 1.4 Сохранение модели на диск

# %% [markdown]
# Обучение модели выполняется посредством функции `train` (см. раздел 1.3). Функция `train` использует глобальные переменные `validationAccToTrain` и `epochsForTraining`. Значение глобальной переменной `validationAccToTrain` соответствует точности (accuracy) на проверочной части датасета, при достижении которой и одновременно максимальной точности в ходе обучения, необходимо сохранить архитектуру и параметры модели на диск. Сохранение модели на диск выполняется посредством функции `net.export`, при этом создаются/перезаписываются два файла: **fashion-mnist-symbol.json**, содержащий информацию, определяющую архитектуру модели, и **fashion-mnist-<номер эпохи>.params**, содержащий параметры модели, полученные в ходе обучения и соответствующие эпохе <номер эпохи>. Значение глобальной переменной `epochsForTraining` соответствует количеству эпох, в течение которых необходимо проводить обучение.

# %% [markdown]
# ## Ссылки

# %% [markdown]
# 1. Официальный сайт mxnet: https://mxnet.apache.org/
