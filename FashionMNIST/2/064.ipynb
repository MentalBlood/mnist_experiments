# %% [markdown]
# # Отчет о создании и обучении на датасете Fashion MNIST модели CNN (гипотеза 1, реализация 2)

# %% [markdown]
# ## Содержание
#
# - Список терминов, специфичных для темы отчета
# - Введение
# - 1 Создание и обучение модели
#  - 1.1 Загрузка датасета
#  - 1.2 Создание модели
#  - 1.3 Обучение модели
#  - 1.4 Сохранение модели на диск
# - 2 Рекомендации по дальнейшему улучшению/развитию модели
# - Ссылки

# %% [markdown]
# ## Список терминов, специфичных для темы отчета
#
# См. раздел "Машинное обучение" документа "Словарь терминов, специфичных для выполняемых работ и изучаемых материалов в период с 25 сентября 2020 г. по 25 ноября 2020 г.".

# %% [markdown]
# ## Введение

# %% [markdown]
# В настоящем отчете приведен код, соответствующий созданию и обучению модели CNN на датасете Fashion MNIST, а также рекомендации по дальнейшему улучшению/развитию модели. Используемый язык программирования – Python. Для создания и обучения модели используются библиотеки MXNet и Gluon.

# %% [markdown]
# ## 1 Создание и обучение модели

# %% [markdown]
# Импортирование необходимых модулей и функций:

# %%
import mxnet as mx
from mxnet.optimizer import Adam
from mxnet import gluon, autograd
from mxnet.gluon import nn
from mxnet.gluon.data.vision import datasets, transforms

# %% [markdown]
# Установка вычислительного контекста (для использования при обучении видеокарты, если это возможно):

# %%
ctx = [mx.gpu() if mx.test_utils.list_gpus() else mx.cpu()]
print('context:', ctx)
# Out:
# context: [gpu(0)]

# %% [markdown]
# ### 1.1 Загрузка датасета

# %% [markdown]
# Загрузка датасета и установка размера батча равным 128:

# %%
batch_size = 128

mnist_train = datasets.FashionMNIST(train=True)
transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.13, 0.31)])
mnist_train = mnist_train.transform_first(transformer)
train_data = gluon.data.DataLoader(
    mnist_train, batch_size=batch_size, shuffle=True, num_workers=4)

mnist_valid = gluon.data.vision.FashionMNIST(train=False)
val_data = gluon.data.DataLoader(
    mnist_valid.transform_first(transformer),
    batch_size=batch_size, num_workers=4)

# %% [markdown]
# ### 1.2 Создание модели

# %% [markdown]
# Создание модели, состоящей из 4 слоев:
# 1. Сверточный слой с параметрами:
# 	- Количество каналов: 8
# 	- Размер ядра свертки: 4х4
# 	- Функция активации: гиперболический тангенс
# 2. Слой пулинга с параметрами:
# 	- Размер ядра пулинга: 2х2
# 	- Шаг: 2
# 3. Полносвязный слой с параметрами:
# 	- Количество нейронов: **64**
# 	- Функция активации: гиперболический тангенс
# 4. Полносвязный слой с параметрами:
# 	- Количество нейронов: 10
# 	- Функция активации: гиперболический тангенс

# %%
net = nn.HybridSequential()
with net.name_scope():
    net.add(nn.Conv2D   (channels=8, kernel_size=4, activation='tanh'))
    net.add(nn.MaxPool2D(pool_size=2, strides=2))
    net.add(nn.Dense    (64, activation='tanh'))
    #                    ^^--- 16 -> 64
    net.add(nn.Dense    (10, activation='tanh'))
net.hybridize()

# %% [markdown]
# ### 1.3 Обучение модели

# %% [markdown]
# Для инициализации сети используется метод Завьера (Xavier). В качестве функции потерь используется SCE (Softmax Cross-Entropy loss). В качестве оптимизатора используется Adam (Adaptive Moment Estimation – метод Адаптивной Оценки Моментов). Обучение производится на протижение 100 эпох.

# %%
epochsForTraining = 100
validationAccToTrain = 0.90

def test(ctx):
    metric = mx.metric.Accuracy()
    for data, label in val_data:
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        output = net(data)
        metric.update([label], [output])

    return metric.get()

def train(net, ctx):
    # Collect all parameters from net and its children, then initialize them.
    net.initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
    # Trainer is for updating parameters with gradient.
    trainer = gluon.Trainer(net.collect_params(), Adam())
    metric = mx.metric.Accuracy()
    loss = gluon.loss.SoftmaxCrossEntropyLoss()

    maxValidationAcc = 0
    for i in range(epochsForTraining):
        # reset data iterator and metric at begining of epoch.
        metric.reset()
        for j, (data, label) in enumerate(train_data):
            # Copy data to ctx if necessary
            data = data.as_in_context(ctx)
            label = label.as_in_context(ctx)
            # Start recording computation graph with record() section.
            # Recorded graphs can then be differentiated with backward.
            with autograd.record():
                output = net(data)
                L = loss(output, label)
                L.backward()
            # take a gradient step with batch_size equal to data.shape[0]
            trainer.step(data.shape[0])
            # update metric at last.
            metric.update([label], [output])

        name, acc = metric.get()
        name, validationAcc = test(ctx)
        epoch = i + 1
        print('epoch', ('{:2.0f}:').format(epoch), '\t', "{:.2f}%".format(acc * 100), '- train set accuracy'
              '\n\t\t', "{:.2f}%".format(validationAcc * 100), '- validation set accuracy')
        if validationAcc > maxValidationAcc:
            maxValidationAcc = validationAcc
            if validationAcc >= validationAccToTrain:
                net.export('exported/064/fashion_mnist', epoch=epoch)
                print('saved epoch', epoch)
        print()
    print('Best result: {:.2f}%'.format(maxValidationAcc * 100))

# %%
train(net, ctx[0])
# Out:
# epoch  1: 	 78.17% - train set accuracy
# 		 84.59% - validation set accuracy
#
# epoch  2: 	 85.76% - train set accuracy
# 		 86.69% - validation set accuracy
#
# epoch  3: 	 87.22% - train set accuracy
# 		 87.63% - validation set accuracy
#
# epoch  4: 	 88.02% - train set accuracy
# 		 88.18% - validation set accuracy
#
# epoch  5: 	 88.64% - train set accuracy
# 		 88.50% - validation set accuracy
#
# epoch  6: 	 88.99% - train set accuracy
# 		 88.31% - validation set accuracy
#
# epoch  7: 	 89.51% - train set accuracy
# 		 89.12% - validation set accuracy
#
# epoch  8: 	 89.85% - train set accuracy
# 		 89.15% - validation set accuracy
#
# epoch  9: 	 90.21% - train set accuracy
# 		 88.84% - validation set accuracy
#
# epoch 10: 	 90.48% - train set accuracy
# 		 89.61% - validation set accuracy
#
# epoch 11: 	 90.77% - train set accuracy
# 		 89.51% - validation set accuracy
#
# epoch 12: 	 90.96% - train set accuracy
# 		 89.84% - validation set accuracy
#
# epoch 13: 	 91.25% - train set accuracy
# 		 89.88% - validation set accuracy
#
# epoch 14: 	 91.43% - train set accuracy
# 		 90.06% - validation set accuracy
# saved epoch 14
#
# epoch 15: 	 91.62% - train set accuracy
# 		 89.87% - validation set accuracy
#
# epoch 16: 	 91.85% - train set accuracy
# 		 90.06% - validation set accuracy
#
# epoch 17: 	 92.03% - train set accuracy
# 		 89.93% - validation set accuracy
#
# epoch 18: 	 92.27% - train set accuracy
# 		 89.74% - validation set accuracy
#
# epoch 19: 	 92.39% - train set accuracy
# 		 90.37% - validation set accuracy
# saved epoch 19
#
# epoch 20: 	 92.52% - train set accuracy
# 		 90.65% - validation set accuracy
# saved epoch 20
#
# epoch 21: 	 92.81% - train set accuracy
# 		 90.44% - validation set accuracy
#
# epoch 22: 	 92.84% - train set accuracy
# 		 90.28% - validation set accuracy
#
# epoch 23: 	 92.90% - train set accuracy
# 		 90.91% - validation set accuracy
# saved epoch 23
#
# epoch 24: 	 93.09% - train set accuracy
# 		 90.44% - validation set accuracy
#
# epoch 25: 	 93.24% - train set accuracy
# 		 90.93% - validation set accuracy
# saved epoch 25
#
# epoch 26: 	 93.36% - train set accuracy
# 		 90.73% - validation set accuracy
#
# epoch 27: 	 93.42% - train set accuracy
# 		 90.23% - validation set accuracy
#
# epoch 28: 	 93.62% - train set accuracy
# 		 90.73% - validation set accuracy
#
# epoch 29: 	 93.69% - train set accuracy
# 		 90.91% - validation set accuracy
#
# epoch 30: 	 93.79% - train set accuracy
# 		 90.78% - validation set accuracy
#
# epoch 31: 	 93.82% - train set accuracy
# 		 90.82% - validation set accuracy
#
# epoch 32: 	 93.96% - train set accuracy
# 		 90.74% - validation set accuracy
#
# epoch 33: 	 94.03% - train set accuracy
# 		 90.86% - validation set accuracy
#
# epoch 34: 	 94.14% - train set accuracy
# 		 91.03% - validation set accuracy
# saved epoch 34
#
# epoch 35: 	 94.30% - train set accuracy
# 		 91.04% - validation set accuracy
# saved epoch 35
#
# epoch 36: 	 94.25% - train set accuracy
# 		 90.82% - validation set accuracy
#
# epoch 37: 	 94.42% - train set accuracy
# 		 90.97% - validation set accuracy
#
# epoch 38: 	 94.37% - train set accuracy
# 		 91.12% - validation set accuracy
# saved epoch 38
#
# epoch 39: 	 94.52% - train set accuracy
# 		 91.25% - validation set accuracy
# saved epoch 39
#
# epoch 40: 	 94.56% - train set accuracy
# 		 90.70% - validation set accuracy
#
# epoch 41: 	 94.77% - train set accuracy
# 		 91.12% - validation set accuracy
#
# epoch 42: 	 94.71% - train set accuracy
# 		 91.19% - validation set accuracy
#
# epoch 43: 	 94.72% - train set accuracy
# 		 91.20% - validation set accuracy
#
# epoch 44: 	 94.86% - train set accuracy
# 		 90.97% - validation set accuracy
#
# epoch 45: 	 94.93% - train set accuracy
# 		 91.05% - validation set accuracy
#
# epoch 46: 	 95.01% - train set accuracy
# 		 90.94% - validation set accuracy
#
# epoch 47: 	 95.10% - train set accuracy
# 		 90.91% - validation set accuracy
#
# epoch 48: 	 95.11% - train set accuracy
# 		 90.91% - validation set accuracy
#
# epoch 49: 	 95.16% - train set accuracy
# 		 91.03% - validation set accuracy
#
# epoch 50: 	 95.23% - train set accuracy
# 		 90.85% - validation set accuracy
#
# epoch 51: 	 95.31% - train set accuracy
# 		 91.04% - validation set accuracy
#
# epoch 52: 	 95.29% - train set accuracy
# 		 90.88% - validation set accuracy
#
# epoch 53: 	 95.45% - train set accuracy
# 		 91.24% - validation set accuracy
#
# epoch 54: 	 95.36% - train set accuracy
# 		 90.99% - validation set accuracy
#
# epoch 55: 	 95.49% - train set accuracy
# 		 90.97% - validation set accuracy
#
# epoch 56: 	 95.53% - train set accuracy
# 		 90.97% - validation set accuracy
#
# epoch 57: 	 95.62% - train set accuracy
# 		 91.04% - validation set accuracy
#
# epoch 58: 	 95.59% - train set accuracy
# 		 91.01% - validation set accuracy
#
# epoch 59: 	 95.67% - train set accuracy
# 		 90.95% - validation set accuracy
#
# epoch 60: 	 95.66% - train set accuracy
# 		 90.83% - validation set accuracy
#
# epoch 61: 	 95.69% - train set accuracy
# 		 90.99% - validation set accuracy
#
# epoch 62: 	 95.74% - train set accuracy
# 		 90.99% - validation set accuracy
#
# epoch 63: 	 95.82% - train set accuracy
# 		 91.01% - validation set accuracy
#
# epoch 64: 	 95.86% - train set accuracy
# 		 90.78% - validation set accuracy
#
# epoch 65: 	 95.80% - train set accuracy
# 		 91.01% - validation set accuracy
#
# epoch 66: 	 95.98% - train set accuracy
# 		 90.84% - validation set accuracy
#
# epoch 67: 	 96.01% - train set accuracy
# 		 90.98% - validation set accuracy
#
# epoch 68: 	 95.99% - train set accuracy
# 		 90.90% - validation set accuracy
#
# epoch 69: 	 96.06% - train set accuracy
# 		 90.67% - validation set accuracy
#
# epoch 70: 	 96.02% - train set accuracy
# 		 91.01% - validation set accuracy
#
# epoch 71: 	 96.12% - train set accuracy
# 		 91.08% - validation set accuracy
#
# epoch 72: 	 96.24% - train set accuracy
# 		 90.90% - validation set accuracy
#
# epoch 73: 	 96.23% - train set accuracy
# 		 90.75% - validation set accuracy
#
# epoch 74: 	 96.22% - train set accuracy
# 		 91.03% - validation set accuracy
#
# epoch 75: 	 96.21% - train set accuracy
# 		 90.97% - validation set accuracy
#
# epoch 76: 	 96.34% - train set accuracy
# 		 91.00% - validation set accuracy
#
# epoch 77: 	 96.32% - train set accuracy
# 		 90.88% - validation set accuracy
#
# epoch 78: 	 96.35% - train set accuracy
# 		 90.69% - validation set accuracy
#
# epoch 79: 	 96.33% - train set accuracy
# 		 91.08% - validation set accuracy
#
# epoch 80: 	 96.31% - train set accuracy
# 		 90.70% - validation set accuracy
#
# epoch 81: 	 96.42% - train set accuracy
# 		 90.78% - validation set accuracy
#
# epoch 82: 	 96.47% - train set accuracy
# 		 90.71% - validation set accuracy
#
# epoch 83: 	 96.47% - train set accuracy
# 		 90.91% - validation set accuracy
#
# epoch 84: 	 96.48% - train set accuracy
# 		 90.83% - validation set accuracy
#
# epoch 85: 	 96.54% - train set accuracy
# 		 90.73% - validation set accuracy
#
# epoch 86: 	 96.50% - train set accuracy
# 		 91.04% - validation set accuracy
#
# epoch 87: 	 96.65% - train set accuracy
# 		 90.88% - validation set accuracy
#
# epoch 88: 	 96.70% - train set accuracy
# 		 90.80% - validation set accuracy
#
# epoch 89: 	 96.75% - train set accuracy
# 		 90.83% - validation set accuracy
#
# epoch 90: 	 96.63% - train set accuracy
# 		 90.77% - validation set accuracy
#
# epoch 91: 	 96.55% - train set accuracy
# 		 90.60% - validation set accuracy
#
# epoch 92: 	 96.73% - train set accuracy
# 		 90.81% - validation set accuracy
#
# epoch 93: 	 96.71% - train set accuracy
# 		 90.92% - validation set accuracy
#
# epoch 94: 	 96.82% - train set accuracy
# 		 91.00% - validation set accuracy
#
# epoch 95: 	 96.86% - train set accuracy
# 		 90.98% - validation set accuracy
#
# epoch 96: 	 96.84% - train set accuracy
# 		 90.97% - validation set accuracy
#
# epoch 97: 	 96.84% - train set accuracy
# 		 90.55% - validation set accuracy
#
# epoch 98: 	 96.84% - train set accuracy
# 		 91.20% - validation set accuracy
#
# epoch 99: 	 96.86% - train set accuracy
# 		 90.65% - validation set accuracy
#
# epoch 100: 	 96.74% - train set accuracy
# 		 90.81% - validation set accuracy
#
# Best result: 91.25%

# %% [markdown]
# Максимальная достигнутая точность на проверочной части датасета составляет **91.25%**

# %% [markdown]
# ### 1.4 Сохранение модели на диск

# %% [markdown]
# Обучение модели выполняется посредством функции `train` (см. раздел 1.3). Функция `train` использует глобальные переменные `validationAccToTrain` и `epochsForTraining`. Значение глобальной переменной `validationAccToTrain` соответствует точности (accuracy) на проверочной части датасета, при достижении которой и одновременно максимальной точности в ходе обучения, необходимо сохранить архитектуру и параметры модели на диск. Сохранение модели на диск выполняется посредством функции `net.export`, при этом создаются/перезаписываются два файла: **fashion-mnist-symbol.json**, содержащий информацию, определяющую архитектуру модели, и **fashion-mnist-<номер эпохи>.params**, содержащий параметры модели, полученные в ходе обучения и соответствующие эпохе <номер эпохи>. Значение глобальной переменной `epochsForTraining` соответствует количеству эпох, в течение которых необходимо проводить обучение.

# %% [markdown]
# ## Ссылки

# %% [markdown]
# 1. Официальный сайт mxnet: https://mxnet.apache.org/
