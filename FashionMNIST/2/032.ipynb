# %% [markdown]
# # Отчет о создании и обучении на датасете Fashion MNIST модели CNN (гипотеза 2, реализация 1)

# %% [markdown]
# ## Содержание
#
# - Список терминов, специфичных для темы отчета
# - Введение
# - 1 Создание и обучение модели
#  - 1.1 Загрузка датасета
#  - 1.2 Создание модели
#  - 1.3 Обучение модели
#  - 1.4 Сохранение модели на диск
# - 2 Рекомендации по дальнейшему улучшению/развитию модели
# - Ссылки

# %% [markdown]
# ## Список терминов, специфичных для темы отчета
#
# См. раздел "Машинное обучение" документа "Словарь терминов, специфичных для выполняемых работ и изучаемых материалов в период с 25 сентября 2020 г. по 25 ноября 2020 г.".

# %% [markdown]
# ## Введение

# %% [markdown]
# В настоящем отчете приведен код, соответствующий созданию и обучению модели CNN на датасете Fashion MNIST, а также рекомендации по дальнейшему улучшению/развитию модели. Используемый язык программирования – Python. Для создания и обучения модели используются библиотеки MXNet и Gluon.

# %% [markdown]
# ## 1 Создание и обучение модели

# %% [markdown]
# Импортирование необходимых модулей и функций:

# %%
import mxnet as mx
from mxnet.optimizer import Adam
from mxnet import gluon, autograd
from mxnet.gluon import nn
from mxnet.gluon.data.vision import datasets, transforms

# %% [markdown]
# Установка вычислительного контекста (для использования при обучении видеокарты, если это возможно):

# %%
ctx = [mx.gpu() if mx.test_utils.list_gpus() else mx.cpu()]
print('context:', ctx)
# Out:
# context: [gpu(0)]

# %% [markdown]
# ### 1.1 Загрузка датасета

# %% [markdown]
# Загрузка датасета и установка размера батча равным 128:

# %%
batch_size = 128

mnist_train = datasets.FashionMNIST(train=True)
transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.13, 0.31)])
mnist_train = mnist_train.transform_first(transformer)
train_data = gluon.data.DataLoader(
    mnist_train, batch_size=batch_size, shuffle=True, num_workers=4)

mnist_valid = gluon.data.vision.FashionMNIST(train=False)
val_data = gluon.data.DataLoader(
    mnist_valid.transform_first(transformer),
    batch_size=batch_size, num_workers=4)

# %% [markdown]
# ### 1.2 Создание модели

# %% [markdown]
# Создание модели, состоящей из 4 слоев:
# 1. Сверточный слой с параметрами:
# 	- Количество каналов: 8
# 	- Размер ядра свертки: 4х4
# 	- Функция активации: гиперболический тангенс
# 2. Слой пулинга с параметрами:
# 	- Размер ядра пулинга: 2х2
# 	- Шаг: 2
# 3. Полносвязный слой с параметрами:
# 	- Количество нейронов: **32**
# 	- Функция активации: гиперболический тангенс
# 4. Полносвязный слой с параметрами:
# 	- Количество нейронов: 10
# 	- Функция активации: гиперболический тангенс

# %%
net = nn.HybridSequential()
with net.name_scope():
    net.add(nn.Conv2D   (channels=8, kernel_size=4, activation='tanh'))
    net.add(nn.MaxPool2D(pool_size=2, strides=2))
    net.add(nn.Dense    (32, activation='tanh'))
    #                    ^^--- 16 -> 32
    net.add(nn.Dense    (10, activation='tanh'))
net.hybridize()

# %% [markdown]
# ### 1.3 Обучение модели

# %% [markdown]
# Для инициализации сети используется метод Завьера (Xavier). В качестве функции потерь используется SCE (Softmax Cross-Entropy loss). В качестве оптимизатора используется Adam (Adaptive Moment Estimation – метод Адаптивной Оценки Моментов). Обучение производится на протижение 100 эпох.

# %%
epochsForTraining = 100
validationAccToTrain = 0.90

def test(ctx):
    metric = mx.metric.Accuracy()
    for data, label in val_data:
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        output = net(data)
        metric.update([label], [output])

    return metric.get()

def train(net, ctx):
    # Collect all parameters from net and its children, then initialize them.
    net.initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
    # Trainer is for updating parameters with gradient.
    trainer = gluon.Trainer(net.collect_params(), Adam())
    metric = mx.metric.Accuracy()
    loss = gluon.loss.SoftmaxCrossEntropyLoss()

    maxValidationAcc = 0
    for i in range(epochsForTraining):
        # reset data iterator and metric at begining of epoch.
        metric.reset()
        for j, (data, label) in enumerate(train_data):
            # Copy data to ctx if necessary
            data = data.as_in_context(ctx)
            label = label.as_in_context(ctx)
            # Start recording computation graph with record() section.
            # Recorded graphs can then be differentiated with backward.
            with autograd.record():
                output = net(data)
                L = loss(output, label)
                L.backward()
            # take a gradient step with batch_size equal to data.shape[0]
            trainer.step(data.shape[0])
            # update metric at last.
            metric.update([label], [output])

        name, acc = metric.get()
        name, validationAcc = test(ctx)
        epoch = i + 1
        print('epoch', ('{:2.0f}:').format(epoch), '\t', "{:.2f}%".format(acc * 100), '- train set accuracy'
              '\n\t\t', "{:.2f}%".format(validationAcc * 100), '- validation set accuracy')
        if validationAcc > maxValidationAcc:
            maxValidationAcc = validationAcc
            if validationAcc >= validationAccToTrain:
                net.export('exported/032/fashion_mnist', epoch=epoch)
                print('saved epoch', epoch)
        print()
    print('Best result: {:.2f}%'.format(maxValidationAcc * 100))

# %%
train(net, ctx[0])
# Out:
# epoch  1: 	 79.75% - train set accuracy
# 		 84.85% - validation set accuracy
#
# epoch  2: 	 85.52% - train set accuracy
# 		 86.07% - validation set accuracy
#
# epoch  3: 	 87.05% - train set accuracy
# 		 87.83% - validation set accuracy
#
# epoch  4: 	 88.10% - train set accuracy
# 		 88.27% - validation set accuracy
#
# epoch  5: 	 88.67% - train set accuracy
# 		 88.67% - validation set accuracy
#
# epoch  6: 	 89.20% - train set accuracy
# 		 88.11% - validation set accuracy
#
# epoch  7: 	 89.65% - train set accuracy
# 		 89.29% - validation set accuracy
#
# epoch  8: 	 90.03% - train set accuracy
# 		 89.11% - validation set accuracy
#
# epoch  9: 	 90.24% - train set accuracy
# 		 89.11% - validation set accuracy
#
# epoch 10: 	 90.59% - train set accuracy
# 		 89.46% - validation set accuracy
#
# epoch 11: 	 90.72% - train set accuracy
# 		 89.80% - validation set accuracy
#
# epoch 12: 	 90.96% - train set accuracy
# 		 89.74% - validation set accuracy
#
# epoch 13: 	 91.20% - train set accuracy
# 		 89.72% - validation set accuracy
#
# epoch 14: 	 91.33% - train set accuracy
# 		 89.70% - validation set accuracy
#
# epoch 15: 	 91.46% - train set accuracy
# 		 89.74% - validation set accuracy
#
# epoch 16: 	 91.66% - train set accuracy
# 		 89.82% - validation set accuracy
#
# epoch 17: 	 91.78% - train set accuracy
# 		 89.67% - validation set accuracy
#
# epoch 18: 	 91.91% - train set accuracy
# 		 89.61% - validation set accuracy
#
# epoch 19: 	 92.10% - train set accuracy
# 		 89.96% - validation set accuracy
#
# epoch 20: 	 92.10% - train set accuracy
# 		 89.59% - validation set accuracy
#
# epoch 21: 	 92.33% - train set accuracy
# 		 89.92% - validation set accuracy
#
# epoch 22: 	 92.38% - train set accuracy
# 		 90.09% - validation set accuracy
# saved epoch 22
#
# epoch 23: 	 92.47% - train set accuracy
# 		 90.25% - validation set accuracy
# saved epoch 23
#
# epoch 24: 	 92.58% - train set accuracy
# 		 90.23% - validation set accuracy
#
# epoch 25: 	 92.71% - train set accuracy
# 		 89.48% - validation set accuracy
#
# epoch 26: 	 92.75% - train set accuracy
# 		 89.85% - validation set accuracy
#
# epoch 27: 	 92.78% - train set accuracy
# 		 90.16% - validation set accuracy
#
# epoch 28: 	 92.88% - train set accuracy
# 		 89.95% - validation set accuracy
#
# epoch 29: 	 93.13% - train set accuracy
# 		 89.77% - validation set accuracy
#
# epoch 30: 	 93.12% - train set accuracy
# 		 90.21% - validation set accuracy
#
# epoch 31: 	 93.26% - train set accuracy
# 		 90.08% - validation set accuracy
#
# epoch 32: 	 93.29% - train set accuracy
# 		 89.96% - validation set accuracy
#
# epoch 33: 	 93.25% - train set accuracy
# 		 89.96% - validation set accuracy
#
# epoch 34: 	 93.44% - train set accuracy
# 		 90.00% - validation set accuracy
#
# epoch 35: 	 93.46% - train set accuracy
# 		 90.11% - validation set accuracy
#
# epoch 36: 	 93.58% - train set accuracy
# 		 90.22% - validation set accuracy
#
# epoch 37: 	 93.69% - train set accuracy
# 		 89.99% - validation set accuracy
#
# epoch 38: 	 93.64% - train set accuracy
# 		 89.81% - validation set accuracy
#
# epoch 39: 	 93.75% - train set accuracy
# 		 89.91% - validation set accuracy
#
# epoch 40: 	 93.70% - train set accuracy
# 		 89.93% - validation set accuracy
#
# epoch 41: 	 93.77% - train set accuracy
# 		 89.97% - validation set accuracy
#
# epoch 42: 	 93.89% - train set accuracy
# 		 90.03% - validation set accuracy
#
# epoch 43: 	 93.89% - train set accuracy
# 		 90.12% - validation set accuracy
#
# epoch 44: 	 93.94% - train set accuracy
# 		 90.03% - validation set accuracy
#
# epoch 45: 	 94.02% - train set accuracy
# 		 89.94% - validation set accuracy
#
# epoch 46: 	 94.01% - train set accuracy
# 		 90.07% - validation set accuracy
#
# epoch 47: 	 94.09% - train set accuracy
# 		 89.98% - validation set accuracy
#
# epoch 48: 	 94.12% - train set accuracy
# 		 90.22% - validation set accuracy
#
# epoch 49: 	 94.15% - train set accuracy
# 		 90.04% - validation set accuracy
#
# epoch 50: 	 94.25% - train set accuracy
# 		 89.88% - validation set accuracy
#
# epoch 51: 	 94.15% - train set accuracy
# 		 90.01% - validation set accuracy
#
# epoch 52: 	 94.27% - train set accuracy
# 		 90.29% - validation set accuracy
# saved epoch 52
#
# epoch 53: 	 94.37% - train set accuracy
# 		 89.94% - validation set accuracy
#
# epoch 54: 	 94.28% - train set accuracy
# 		 89.92% - validation set accuracy
#
# epoch 55: 	 94.42% - train set accuracy
# 		 90.00% - validation set accuracy
#
# epoch 56: 	 94.47% - train set accuracy
# 		 89.85% - validation set accuracy
#
# epoch 57: 	 94.49% - train set accuracy
# 		 90.29% - validation set accuracy
#
# epoch 58: 	 94.53% - train set accuracy
# 		 90.06% - validation set accuracy
#
# epoch 59: 	 94.60% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 60: 	 94.42% - train set accuracy
# 		 89.85% - validation set accuracy
#
# epoch 61: 	 94.57% - train set accuracy
# 		 89.73% - validation set accuracy
#
# epoch 62: 	 94.67% - train set accuracy
# 		 89.91% - validation set accuracy
#
# epoch 63: 	 94.65% - train set accuracy
# 		 89.96% - validation set accuracy
#
# epoch 64: 	 94.79% - train set accuracy
# 		 90.18% - validation set accuracy
#
# epoch 65: 	 94.78% - train set accuracy
# 		 90.14% - validation set accuracy
#
# epoch 66: 	 94.80% - train set accuracy
# 		 90.07% - validation set accuracy
#
# epoch 67: 	 94.81% - train set accuracy
# 		 90.02% - validation set accuracy
#
# epoch 68: 	 94.89% - train set accuracy
# 		 89.93% - validation set accuracy
#
# epoch 69: 	 94.88% - train set accuracy
# 		 90.08% - validation set accuracy
#
# epoch 70: 	 94.89% - train set accuracy
# 		 89.79% - validation set accuracy
#
# epoch 71: 	 94.83% - train set accuracy
# 		 89.91% - validation set accuracy
#
# epoch 72: 	 94.95% - train set accuracy
# 		 89.96% - validation set accuracy
#
# epoch 73: 	 94.99% - train set accuracy
# 		 89.97% - validation set accuracy
#
# epoch 74: 	 94.99% - train set accuracy
# 		 90.01% - validation set accuracy
#
# epoch 75: 	 94.89% - train set accuracy
# 		 89.96% - validation set accuracy
#
# epoch 76: 	 95.07% - train set accuracy
# 		 90.13% - validation set accuracy
#
# epoch 77: 	 95.05% - train set accuracy
# 		 90.09% - validation set accuracy
#
# epoch 78: 	 95.05% - train set accuracy
# 		 89.82% - validation set accuracy
#
# epoch 79: 	 95.08% - train set accuracy
# 		 89.92% - validation set accuracy
#
# epoch 80: 	 95.17% - train set accuracy
# 		 90.01% - validation set accuracy
#
# epoch 81: 	 95.16% - train set accuracy
# 		 90.03% - validation set accuracy
#
# epoch 82: 	 95.19% - train set accuracy
# 		 89.78% - validation set accuracy
#
# epoch 83: 	 95.26% - train set accuracy
# 		 89.78% - validation set accuracy
#
# epoch 84: 	 95.25% - train set accuracy
# 		 89.82% - validation set accuracy
#
# epoch 85: 	 95.31% - train set accuracy
# 		 89.92% - validation set accuracy
#
# epoch 86: 	 95.37% - train set accuracy
# 		 90.09% - validation set accuracy
#
# epoch 87: 	 95.32% - train set accuracy
# 		 90.12% - validation set accuracy
#
# epoch 88: 	 95.32% - train set accuracy
# 		 89.69% - validation set accuracy
#
# epoch 89: 	 95.25% - train set accuracy
# 		 89.81% - validation set accuracy
#
# epoch 90: 	 95.41% - train set accuracy
# 		 90.07% - validation set accuracy
#
# epoch 91: 	 95.44% - train set accuracy
# 		 89.84% - validation set accuracy
#
# epoch 92: 	 95.39% - train set accuracy
# 		 89.96% - validation set accuracy
#
# epoch 93: 	 95.45% - train set accuracy
# 		 90.02% - validation set accuracy
#
# epoch 94: 	 95.48% - train set accuracy
# 		 89.56% - validation set accuracy
#
# epoch 95: 	 95.33% - train set accuracy
# 		 89.92% - validation set accuracy
#
# epoch 96: 	 95.44% - train set accuracy
# 		 90.03% - validation set accuracy
#
# epoch 97: 	 95.52% - train set accuracy
# 		 90.03% - validation set accuracy
#
# epoch 98: 	 95.48% - train set accuracy
# 		 89.77% - validation set accuracy
#
# epoch 99: 	 95.59% - train set accuracy
# 		 89.84% - validation set accuracy
#
# epoch 100: 	 95.52% - train set accuracy
# 		 89.76% - validation set accuracy
#
# Best result: 90.29%

# %% [markdown]
# Максимальная достигнутая точность на проверочной части датасета составляет **90.29%**

# %% [markdown]
# ### 1.4 Сохранение модели на диск

# %% [markdown]
# Обучение модели выполняется посредством функции `train` (см. раздел 1.3). Функция `train` использует глобальные переменные `validationAccToTrain` и `epochsForTraining`. Значение глобальной переменной `validationAccToTrain` соответствует точности (accuracy) на проверочной части датасета, при достижении которой и одновременно максимальной точности в ходе обучения, необходимо сохранить архитектуру и параметры модели на диск. Сохранение модели на диск выполняется посредством функции `net.export`, при этом создаются/перезаписываются два файла: **fashion-mnist-symbol.json**, содержащий информацию, определяющую архитектуру модели, и **fashion-mnist-<номер эпохи>.params**, содержащий параметры модели, полученные в ходе обучения и соответствующие эпохе <номер эпохи>. Значение глобальной переменной `epochsForTraining` соответствует количеству эпох, в течение которых необходимо проводить обучение.

# %% [markdown]
# ## Ссылки

# %% [markdown]
# 1. Официальный сайт mxnet: https://mxnet.apache.org/
