# %% [markdown]
# # Отчет о создании и обучении на датасете Fashion MNIST модели CNN (гипотеза 6, реализация 3)

# %% [markdown]
# ## Содержание
#
# - Список терминов, специфичных для темы отчета
# - Введение
# - 1 Создание и обучение модели
#  - 1.1 Загрузка датасета
#  - 1.2 Создание модели
#  - 1.3 Обучение модели
#  - 1.4 Сохранение модели на диск
# - 2 Рекомендации по дальнейшему улучшению/развитию модели
# - Ссылки

# %% [markdown]
# ## Список терминов, специфичных для темы отчета
#
# См. раздел "Машинное обучение" документа "Словарь терминов, специфичных для выполняемых работ и изучаемых материалов в период с 25 сентября 2020 г. по 25 ноября 2020 г.".

# %% [markdown]
# ## Введение

# %% [markdown]
# В настоящем отчете приведен код, соответствующий созданию и обучению модели CNN на датасете Fashion MNIST, а также рекомендации по дальнейшему улучшению/развитию модели. Используемый язык программирования – Python. Для создания и обучения модели используются библиотеки MXNet и Gluon.

# %% [markdown]
# ## 1 Создание и обучение модели

# %% [markdown]
# Импортирование необходимых модулей и функций:

# %%
import mxnet as mx
from mxnet.optimizer import Adam
from mxnet import gluon, autograd
from mxnet.gluon import nn
from mxnet.gluon.data.vision import datasets, transforms

# %% [markdown]
# Установка вычислительного контекста (для использования при обучении видеокарты, если это возможно):

# %%
ctx = [mx.gpu() if mx.test_utils.list_gpus() else mx.cpu()]
print('context:', ctx)
# Out:
# context: [gpu(0)]

# %% [markdown]
# ### 1.1 Загрузка датасета

# %% [markdown]
# Загрузка датасета и установка размера батча равным 128:

# %%
batch_size = 128

mnist_train = datasets.FashionMNIST(train=True)
transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.13, 0.31)])
mnist_train = mnist_train.transform_first(transformer)
train_data = gluon.data.DataLoader(
    mnist_train, batch_size=batch_size, shuffle=True, num_workers=4)

mnist_valid = gluon.data.vision.FashionMNIST(train=False)
val_data = gluon.data.DataLoader(
    mnist_valid.transform_first(transformer),
    batch_size=batch_size, num_workers=4)

# %% [markdown]
# ### 1.2 Создание модели

# %% [markdown]
# Создание модели, состоящей из 4 слоев:
# 1. Сверточный слой с параметрами:
# 	- Количество каналов: 8
# 	- Размер ядра свертки: 4х4
# 	- Функция активации: гиперболический тангенс
# 2. Слой пулинга с параметрами:
# 	- Размер ядра пулинга: 2х2
# 	- Шаг: 2
# 3. Полносвязный слой с параметрами:
# 	- Количество нейронов: 16
# 	- Функция активации: гиперболический тангенс
# 4. Полносвязный слой с параметрами:
# 	- Количество нейронов: 10
# 	- Функция активации: гиперболический тангенс

# %%
net = nn.HybridSequential()
with net.name_scope():
    net.add(nn.Conv2D   (channels=8, kernel_size=4, activation='tanh'))
    net.add(nn.MaxPool2D(pool_size=2, strides=2))
    net.add(nn.Dense    (16, activation='tanh'))
    net.add(nn.Dense    (10, activation='tanh'))
net.hybridize()

# %% [markdown]
# ### 1.3 Обучение модели

# %% [markdown]
# Для инициализации сети используется метод Завьера (Xavier). В качестве функции потерь используется SCE (Softmax Cross-Entropy loss). В качестве оптимизатора используется Adam (Adaptive Moment Estimation – метод Адаптивной Оценки Моментов). Обучение производится на протижение 100 эпох.

# %%
epochsForTraining = 300
#                   ^^^--- 100 -> 300
validationAccToTrain = 0.90

def test(ctx):
    metric = mx.metric.Accuracy()
    for data, label in val_data:
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        output = net(data)
        metric.update([label], [output])

    return metric.get()

def train(net, ctx):
    # Collect all parameters from net and its children, then initialize them.
    net.initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
    # Trainer is for updating parameters with gradient.
    trainer = gluon.Trainer(net.collect_params(), Adam())
    metric = mx.metric.Accuracy()
    loss = gluon.loss.SoftmaxCrossEntropyLoss()

    maxValidationAcc = 0
    for i in range(epochsForTraining):
        # reset data iterator and metric at begining of epoch.
        metric.reset()
        for j, (data, label) in enumerate(train_data):
            # Copy data to ctx if necessary
            data = data.as_in_context(ctx)
            label = label.as_in_context(ctx)
            # Start recording computation graph with record() section.
            # Recorded graphs can then be differentiated with backward.
            with autograd.record():
                output = net(data)
                L = loss(output, label)
                L.backward()
            # take a gradient step with batch_size equal to data.shape[0]
            trainer.step(data.shape[0])
            # update metric at last.
            metric.update([label], [output])

        name, acc = metric.get()
        name, validationAcc = test(ctx)
        epoch = i + 1
        print('epoch', ('{:2.0f}:').format(epoch), '\t', "{:.2f}%".format(acc * 100), '- train set accuracy'
              '\n\t\t', "{:.2f}%".format(validationAcc * 100), '- validation set accuracy')
        if validationAcc > maxValidationAcc:
            maxValidationAcc = validationAcc
            if validationAcc >= validationAccToTrain:
                net.export('exported/300/fashion_mnist', epoch=epoch)
                print('saved epoch', epoch)
        print()
    print('Best result: {:.2f}%'.format(maxValidationAcc * 100))

# %%
train(net, ctx[0])
# Out:
# epoch  1: 	 76.77% - train set accuracy
# 		 83.92% - validation set accuracy
#
# epoch  2: 	 84.82% - train set accuracy
# 		 86.00% - validation set accuracy
#
# epoch  3: 	 86.61% - train set accuracy
# 		 87.07% - validation set accuracy
#
# epoch  4: 	 87.37% - train set accuracy
# 		 87.81% - validation set accuracy
#
# epoch  5: 	 87.93% - train set accuracy
# 		 88.04% - validation set accuracy
#
# epoch  6: 	 88.35% - train set accuracy
# 		 88.05% - validation set accuracy
#
# epoch  7: 	 88.62% - train set accuracy
# 		 88.51% - validation set accuracy
#
# epoch  8: 	 89.11% - train set accuracy
# 		 88.52% - validation set accuracy
#
# epoch  9: 	 89.38% - train set accuracy
# 		 88.54% - validation set accuracy
#
# epoch 10: 	 89.33% - train set accuracy
# 		 89.13% - validation set accuracy
#
# epoch 11: 	 89.74% - train set accuracy
# 		 88.99% - validation set accuracy
#
# epoch 12: 	 89.92% - train set accuracy
# 		 89.15% - validation set accuracy
#
# epoch 13: 	 90.02% - train set accuracy
# 		 89.19% - validation set accuracy
#
# epoch 14: 	 90.31% - train set accuracy
# 		 89.61% - validation set accuracy
#
# epoch 15: 	 90.46% - train set accuracy
# 		 89.04% - validation set accuracy
#
# epoch 16: 	 90.57% - train set accuracy
# 		 89.57% - validation set accuracy
#
# epoch 17: 	 90.70% - train set accuracy
# 		 88.64% - validation set accuracy
#
# epoch 18: 	 90.80% - train set accuracy
# 		 89.53% - validation set accuracy
#
# epoch 19: 	 90.97% - train set accuracy
# 		 88.11% - validation set accuracy
#
# epoch 20: 	 90.89% - train set accuracy
# 		 89.60% - validation set accuracy
#
# epoch 21: 	 91.09% - train set accuracy
# 		 89.41% - validation set accuracy
#
# epoch 22: 	 91.03% - train set accuracy
# 		 89.41% - validation set accuracy
#
# epoch 23: 	 91.34% - train set accuracy
# 		 89.40% - validation set accuracy
#
# epoch 24: 	 91.30% - train set accuracy
# 		 89.61% - validation set accuracy
#
# epoch 25: 	 91.41% - train set accuracy
# 		 89.57% - validation set accuracy
#
# epoch 26: 	 91.58% - train set accuracy
# 		 89.67% - validation set accuracy
#
# epoch 27: 	 91.61% - train set accuracy
# 		 89.49% - validation set accuracy
#
# epoch 28: 	 91.69% - train set accuracy
# 		 89.77% - validation set accuracy
#
# epoch 29: 	 91.63% - train set accuracy
# 		 89.57% - validation set accuracy
#
# epoch 30: 	 91.71% - train set accuracy
# 		 89.51% - validation set accuracy
#
# epoch 31: 	 91.92% - train set accuracy
# 		 89.68% - validation set accuracy
#
# epoch 32: 	 91.92% - train set accuracy
# 		 89.60% - validation set accuracy
#
# epoch 33: 	 91.95% - train set accuracy
# 		 89.74% - validation set accuracy
#
# epoch 34: 	 91.97% - train set accuracy
# 		 89.72% - validation set accuracy
#
# epoch 35: 	 91.90% - train set accuracy
# 		 89.61% - validation set accuracy
#
# epoch 36: 	 92.23% - train set accuracy
# 		 89.66% - validation set accuracy
#
# epoch 37: 	 92.09% - train set accuracy
# 		 89.65% - validation set accuracy
#
# epoch 38: 	 92.13% - train set accuracy
# 		 89.66% - validation set accuracy
#
# epoch 39: 	 92.22% - train set accuracy
# 		 89.65% - validation set accuracy
#
# epoch 40: 	 92.29% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 41: 	 92.29% - train set accuracy
# 		 89.83% - validation set accuracy
#
# epoch 42: 	 92.37% - train set accuracy
# 		 89.59% - validation set accuracy
#
# epoch 43: 	 92.45% - train set accuracy
# 		 89.92% - validation set accuracy
#
# epoch 44: 	 92.48% - train set accuracy
# 		 89.74% - validation set accuracy
#
# epoch 45: 	 92.49% - train set accuracy
# 		 89.42% - validation set accuracy
#
# epoch 46: 	 92.51% - train set accuracy
# 		 89.68% - validation set accuracy
#
# epoch 47: 	 92.49% - train set accuracy
# 		 89.35% - validation set accuracy
#
# epoch 48: 	 92.58% - train set accuracy
# 		 89.62% - validation set accuracy
#
# epoch 49: 	 92.63% - train set accuracy
# 		 89.22% - validation set accuracy
#
# epoch 50: 	 92.58% - train set accuracy
# 		 89.54% - validation set accuracy
#
# epoch 51: 	 92.76% - train set accuracy
# 		 89.67% - validation set accuracy
#
# epoch 52: 	 92.70% - train set accuracy
# 		 89.66% - validation set accuracy
#
# epoch 53: 	 92.73% - train set accuracy
# 		 89.51% - validation set accuracy
#
# epoch 54: 	 92.85% - train set accuracy
# 		 89.64% - validation set accuracy
#
# epoch 55: 	 92.76% - train set accuracy
# 		 89.58% - validation set accuracy
#
# epoch 56: 	 92.80% - train set accuracy
# 		 89.52% - validation set accuracy
#
# epoch 57: 	 92.86% - train set accuracy
# 		 89.49% - validation set accuracy
#
# epoch 58: 	 92.96% - train set accuracy
# 		 89.63% - validation set accuracy
#
# epoch 59: 	 92.84% - train set accuracy
# 		 89.43% - validation set accuracy
#
# epoch 60: 	 92.91% - train set accuracy
# 		 89.65% - validation set accuracy
#
# epoch 61: 	 93.02% - train set accuracy
# 		 89.38% - validation set accuracy
#
# epoch 62: 	 92.95% - train set accuracy
# 		 89.44% - validation set accuracy
#
# epoch 63: 	 93.00% - train set accuracy
# 		 89.42% - validation set accuracy
#
# epoch 64: 	 93.06% - train set accuracy
# 		 89.22% - validation set accuracy
#
# epoch 65: 	 93.08% - train set accuracy
# 		 89.29% - validation set accuracy
#
# epoch 66: 	 93.09% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 67: 	 93.22% - train set accuracy
# 		 89.44% - validation set accuracy
#
# epoch 68: 	 93.18% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 69: 	 93.21% - train set accuracy
# 		 89.60% - validation set accuracy
#
# epoch 70: 	 93.22% - train set accuracy
# 		 89.69% - validation set accuracy
#
# epoch 71: 	 93.28% - train set accuracy
# 		 88.98% - validation set accuracy
#
# epoch 72: 	 93.25% - train set accuracy
# 		 89.47% - validation set accuracy
#
# epoch 73: 	 93.26% - train set accuracy
# 		 89.52% - validation set accuracy
#
# epoch 74: 	 93.25% - train set accuracy
# 		 89.27% - validation set accuracy
#
# epoch 75: 	 93.26% - train set accuracy
# 		 89.57% - validation set accuracy
#
# epoch 76: 	 93.31% - train set accuracy
# 		 89.78% - validation set accuracy
#
# epoch 77: 	 93.36% - train set accuracy
# 		 89.75% - validation set accuracy
#
# epoch 78: 	 93.32% - train set accuracy
# 		 89.24% - validation set accuracy
#
# epoch 79: 	 93.30% - train set accuracy
# 		 89.30% - validation set accuracy
#
# epoch 80: 	 93.36% - train set accuracy
# 		 89.46% - validation set accuracy
#
# epoch 81: 	 93.46% - train set accuracy
# 		 89.31% - validation set accuracy
#
# epoch 82: 	 93.41% - train set accuracy
# 		 89.11% - validation set accuracy
#
# epoch 83: 	 93.40% - train set accuracy
# 		 89.34% - validation set accuracy
#
# epoch 84: 	 93.47% - train set accuracy
# 		 89.30% - validation set accuracy
#
# epoch 85: 	 93.50% - train set accuracy
# 		 89.39% - validation set accuracy
#
# epoch 86: 	 93.58% - train set accuracy
# 		 89.48% - validation set accuracy
#
# epoch 87: 	 93.45% - train set accuracy
# 		 89.20% - validation set accuracy
#
# epoch 88: 	 93.57% - train set accuracy
# 		 89.21% - validation set accuracy
#
# epoch 89: 	 93.47% - train set accuracy
# 		 89.44% - validation set accuracy
#
# epoch 90: 	 93.64% - train set accuracy
# 		 88.97% - validation set accuracy
#
# epoch 91: 	 93.60% - train set accuracy
# 		 89.31% - validation set accuracy
#
# epoch 92: 	 93.57% - train set accuracy
# 		 89.17% - validation set accuracy
#
# epoch 93: 	 93.57% - train set accuracy
# 		 89.27% - validation set accuracy
#
# epoch 94: 	 93.65% - train set accuracy
# 		 89.46% - validation set accuracy
#
# epoch 95: 	 93.64% - train set accuracy
# 		 89.24% - validation set accuracy
#
# epoch 96: 	 93.69% - train set accuracy
# 		 89.53% - validation set accuracy
#
# epoch 97: 	 93.72% - train set accuracy
# 		 89.12% - validation set accuracy
#
# epoch 98: 	 93.78% - train set accuracy
# 		 89.00% - validation set accuracy
#
# epoch 99: 	 93.81% - train set accuracy
# 		 89.33% - validation set accuracy
#
# epoch 100: 	 93.68% - train set accuracy
# 		 89.31% - validation set accuracy
#
# epoch 101: 	 93.72% - train set accuracy
# 		 89.28% - validation set accuracy
#
# epoch 102: 	 93.75% - train set accuracy
# 		 89.34% - validation set accuracy
#
# epoch 103: 	 93.73% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 104: 	 93.81% - train set accuracy
# 		 89.11% - validation set accuracy
#
# epoch 105: 	 93.70% - train set accuracy
# 		 89.56% - validation set accuracy
#
# epoch 106: 	 93.87% - train set accuracy
# 		 89.39% - validation set accuracy
#
# epoch 107: 	 93.88% - train set accuracy
# 		 89.27% - validation set accuracy
#
# epoch 108: 	 93.75% - train set accuracy
# 		 89.23% - validation set accuracy
#
# epoch 109: 	 93.93% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 110: 	 93.86% - train set accuracy
# 		 89.08% - validation set accuracy
#
# epoch 111: 	 93.83% - train set accuracy
# 		 88.92% - validation set accuracy
#
# epoch 112: 	 93.96% - train set accuracy
# 		 89.09% - validation set accuracy
#
# epoch 113: 	 93.86% - train set accuracy
# 		 89.27% - validation set accuracy
#
# epoch 114: 	 93.95% - train set accuracy
# 		 89.26% - validation set accuracy
#
# epoch 115: 	 93.92% - train set accuracy
# 		 89.25% - validation set accuracy
#
# epoch 116: 	 93.96% - train set accuracy
# 		 89.32% - validation set accuracy
#
# epoch 117: 	 93.88% - train set accuracy
# 		 89.04% - validation set accuracy
#
# epoch 118: 	 93.89% - train set accuracy
# 		 89.13% - validation set accuracy
#
# epoch 119: 	 94.02% - train set accuracy
# 		 89.16% - validation set accuracy
#
# epoch 120: 	 94.06% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 121: 	 94.02% - train set accuracy
# 		 89.09% - validation set accuracy
#
# epoch 122: 	 94.00% - train set accuracy
# 		 89.09% - validation set accuracy
#
# epoch 123: 	 94.01% - train set accuracy
# 		 89.27% - validation set accuracy
#
# epoch 124: 	 94.02% - train set accuracy
# 		 89.02% - validation set accuracy
#
# epoch 125: 	 94.06% - train set accuracy
# 		 89.20% - validation set accuracy
#
# epoch 126: 	 94.16% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 127: 	 94.09% - train set accuracy
# 		 89.26% - validation set accuracy
#
# epoch 128: 	 94.05% - train set accuracy
# 		 89.29% - validation set accuracy
#
# epoch 129: 	 94.21% - train set accuracy
# 		 89.23% - validation set accuracy
#
# epoch 130: 	 94.20% - train set accuracy
# 		 89.25% - validation set accuracy
#
# epoch 131: 	 94.08% - train set accuracy
# 		 89.34% - validation set accuracy
#
# epoch 132: 	 94.14% - train set accuracy
# 		 89.08% - validation set accuracy
#
# epoch 133: 	 94.16% - train set accuracy
# 		 89.10% - validation set accuracy
#
# epoch 134: 	 94.17% - train set accuracy
# 		 89.21% - validation set accuracy
#
# epoch 135: 	 94.23% - train set accuracy
# 		 88.84% - validation set accuracy
#
# epoch 136: 	 94.23% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 137: 	 94.21% - train set accuracy
# 		 89.19% - validation set accuracy
#
# epoch 138: 	 94.22% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 139: 	 94.16% - train set accuracy
# 		 89.23% - validation set accuracy
#
# epoch 140: 	 94.22% - train set accuracy
# 		 89.21% - validation set accuracy
#
# epoch 141: 	 94.19% - train set accuracy
# 		 89.33% - validation set accuracy
#
# epoch 142: 	 94.30% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 143: 	 94.22% - train set accuracy
# 		 89.00% - validation set accuracy
#
# epoch 144: 	 94.22% - train set accuracy
# 		 89.13% - validation set accuracy
#
# epoch 145: 	 94.29% - train set accuracy
# 		 89.19% - validation set accuracy
#
# epoch 146: 	 94.13% - train set accuracy
# 		 89.12% - validation set accuracy
#
# epoch 147: 	 94.25% - train set accuracy
# 		 89.10% - validation set accuracy
#
# epoch 148: 	 94.18% - train set accuracy
# 		 88.99% - validation set accuracy
#
# epoch 149: 	 94.28% - train set accuracy
# 		 88.98% - validation set accuracy
#
# epoch 150: 	 94.33% - train set accuracy
# 		 89.03% - validation set accuracy
#
# epoch 151: 	 94.39% - train set accuracy
# 		 88.83% - validation set accuracy
#
# epoch 152: 	 94.29% - train set accuracy
# 		 89.18% - validation set accuracy
#
# epoch 153: 	 94.22% - train set accuracy
# 		 89.11% - validation set accuracy
#
# epoch 154: 	 94.39% - train set accuracy
# 		 89.17% - validation set accuracy
#
# epoch 155: 	 94.36% - train set accuracy
# 		 89.14% - validation set accuracy
#
# epoch 156: 	 94.35% - train set accuracy
# 		 88.91% - validation set accuracy
#
# epoch 157: 	 94.37% - train set accuracy
# 		 89.16% - validation set accuracy
#
# epoch 158: 	 94.44% - train set accuracy
# 		 88.93% - validation set accuracy
#
# epoch 159: 	 94.37% - train set accuracy
# 		 89.28% - validation set accuracy
#
# epoch 160: 	 94.42% - train set accuracy
# 		 88.87% - validation set accuracy
#
# epoch 161: 	 94.33% - train set accuracy
# 		 88.95% - validation set accuracy
#
# epoch 162: 	 94.35% - train set accuracy
# 		 88.86% - validation set accuracy
#
# epoch 163: 	 94.44% - train set accuracy
# 		 88.98% - validation set accuracy
#
# epoch 164: 	 94.47% - train set accuracy
# 		 88.87% - validation set accuracy
#
# epoch 165: 	 94.38% - train set accuracy
# 		 89.02% - validation set accuracy
#
# epoch 166: 	 94.43% - train set accuracy
# 		 88.84% - validation set accuracy
#
# epoch 167: 	 94.49% - train set accuracy
# 		 88.99% - validation set accuracy
#
# epoch 168: 	 94.53% - train set accuracy
# 		 88.81% - validation set accuracy
#
# epoch 169: 	 94.43% - train set accuracy
# 		 88.95% - validation set accuracy
#
# epoch 170: 	 94.45% - train set accuracy
# 		 89.05% - validation set accuracy
#
# epoch 171: 	 94.47% - train set accuracy
# 		 89.00% - validation set accuracy
#
# epoch 172: 	 94.47% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 173: 	 94.49% - train set accuracy
# 		 88.80% - validation set accuracy
#
# epoch 174: 	 94.47% - train set accuracy
# 		 89.14% - validation set accuracy
#
# epoch 175: 	 94.55% - train set accuracy
# 		 88.82% - validation set accuracy
#
# epoch 176: 	 94.48% - train set accuracy
# 		 88.83% - validation set accuracy
#
# epoch 177: 	 94.49% - train set accuracy
# 		 88.85% - validation set accuracy
#
# epoch 178: 	 94.46% - train set accuracy
# 		 89.04% - validation set accuracy
#
# epoch 179: 	 94.56% - train set accuracy
# 		 88.87% - validation set accuracy
#
# epoch 180: 	 94.57% - train set accuracy
# 		 88.92% - validation set accuracy
#
# epoch 181: 	 94.54% - train set accuracy
# 		 88.81% - validation set accuracy
#
# epoch 182: 	 94.55% - train set accuracy
# 		 88.88% - validation set accuracy
#
# epoch 183: 	 94.50% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 184: 	 94.58% - train set accuracy
# 		 88.92% - validation set accuracy
#
# epoch 185: 	 94.54% - train set accuracy
# 		 88.77% - validation set accuracy
#
# epoch 186: 	 94.49% - train set accuracy
# 		 88.93% - validation set accuracy
#
# epoch 187: 	 94.53% - train set accuracy
# 		 88.45% - validation set accuracy
#
# epoch 188: 	 94.51% - train set accuracy
# 		 88.80% - validation set accuracy
#
# epoch 189: 	 94.56% - train set accuracy
# 		 88.94% - validation set accuracy
#
# epoch 190: 	 94.56% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 191: 	 94.53% - train set accuracy
# 		 88.82% - validation set accuracy
#
# epoch 192: 	 94.63% - train set accuracy
# 		 88.94% - validation set accuracy
#
# epoch 193: 	 94.62% - train set accuracy
# 		 89.04% - validation set accuracy
#
# epoch 194: 	 94.56% - train set accuracy
# 		 88.80% - validation set accuracy
#
# epoch 195: 	 94.74% - train set accuracy
# 		 88.97% - validation set accuracy
#
# epoch 196: 	 94.58% - train set accuracy
# 		 88.93% - validation set accuracy
#
# epoch 197: 	 94.71% - train set accuracy
# 		 88.76% - validation set accuracy
#
# epoch 198: 	 94.54% - train set accuracy
# 		 89.17% - validation set accuracy
#
# epoch 199: 	 94.66% - train set accuracy
# 		 88.84% - validation set accuracy
#
# epoch 200: 	 94.64% - train set accuracy
# 		 88.79% - validation set accuracy
#
# epoch 201: 	 94.73% - train set accuracy
# 		 88.88% - validation set accuracy
#
# epoch 202: 	 94.67% - train set accuracy
# 		 89.03% - validation set accuracy
#
# epoch 203: 	 94.73% - train set accuracy
# 		 88.85% - validation set accuracy
#
# epoch 204: 	 94.67% - train set accuracy
# 		 88.68% - validation set accuracy
#
# epoch 205: 	 94.71% - train set accuracy
# 		 89.07% - validation set accuracy
#
# epoch 206: 	 94.77% - train set accuracy
# 		 88.73% - validation set accuracy
#
# epoch 207: 	 94.74% - train set accuracy
# 		 89.02% - validation set accuracy
#
# epoch 208: 	 94.65% - train set accuracy
# 		 88.96% - validation set accuracy
#
# epoch 209: 	 94.65% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 210: 	 94.63% - train set accuracy
# 		 88.79% - validation set accuracy
#
# epoch 211: 	 94.67% - train set accuracy
# 		 88.93% - validation set accuracy
#
# epoch 212: 	 94.73% - train set accuracy
# 		 88.85% - validation set accuracy
#
# epoch 213: 	 94.80% - train set accuracy
# 		 88.81% - validation set accuracy
#
# epoch 214: 	 94.78% - train set accuracy
# 		 88.83% - validation set accuracy
#
# epoch 215: 	 94.73% - train set accuracy
# 		 88.85% - validation set accuracy
#
# epoch 216: 	 94.77% - train set accuracy
# 		 88.86% - validation set accuracy
#
# epoch 217: 	 94.80% - train set accuracy
# 		 88.66% - validation set accuracy
#
# epoch 218: 	 94.75% - train set accuracy
# 		 89.09% - validation set accuracy
#
# epoch 219: 	 94.73% - train set accuracy
# 		 88.76% - validation set accuracy
#
# epoch 220: 	 94.88% - train set accuracy
# 		 88.97% - validation set accuracy
#
# epoch 221: 	 94.77% - train set accuracy
# 		 89.02% - validation set accuracy
#
# epoch 222: 	 94.80% - train set accuracy
# 		 88.73% - validation set accuracy
#
# epoch 223: 	 94.70% - train set accuracy
# 		 88.90% - validation set accuracy
#
# epoch 224: 	 94.77% - train set accuracy
# 		 88.79% - validation set accuracy
#
# epoch 225: 	 94.69% - train set accuracy
# 		 88.98% - validation set accuracy
#
# epoch 226: 	 94.79% - train set accuracy
# 		 88.96% - validation set accuracy
#
# epoch 227: 	 94.85% - train set accuracy
# 		 88.62% - validation set accuracy
#
# epoch 228: 	 94.77% - train set accuracy
# 		 88.80% - validation set accuracy
#
# epoch 229: 	 94.75% - train set accuracy
# 		 88.95% - validation set accuracy
#
# epoch 230: 	 94.84% - train set accuracy
# 		 88.83% - validation set accuracy
#
# epoch 231: 	 94.87% - train set accuracy
# 		 88.57% - validation set accuracy
#
# epoch 232: 	 94.75% - train set accuracy
# 		 88.95% - validation set accuracy
#
# epoch 233: 	 94.87% - train set accuracy
# 		 88.67% - validation set accuracy
#
# epoch 234: 	 94.84% - train set accuracy
# 		 88.75% - validation set accuracy
#
# epoch 235: 	 94.84% - train set accuracy
# 		 89.00% - validation set accuracy
#
# epoch 236: 	 94.82% - train set accuracy
# 		 88.91% - validation set accuracy
#
# epoch 237: 	 94.89% - train set accuracy
# 		 88.94% - validation set accuracy
#
# epoch 238: 	 94.91% - train set accuracy
# 		 88.82% - validation set accuracy
#
# epoch 239: 	 94.90% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 240: 	 94.89% - train set accuracy
# 		 88.44% - validation set accuracy
#
# epoch 241: 	 94.83% - train set accuracy
# 		 88.93% - validation set accuracy
#
# epoch 242: 	 94.84% - train set accuracy
# 		 89.01% - validation set accuracy
#
# epoch 243: 	 94.83% - train set accuracy
# 		 88.83% - validation set accuracy
#
# epoch 244: 	 94.91% - train set accuracy
# 		 88.52% - validation set accuracy
#
# epoch 245: 	 94.79% - train set accuracy
# 		 88.87% - validation set accuracy
#
# epoch 246: 	 94.89% - train set accuracy
# 		 89.11% - validation set accuracy
#
# epoch 247: 	 94.86% - train set accuracy
# 		 89.04% - validation set accuracy
#
# epoch 248: 	 94.93% - train set accuracy
# 		 88.74% - validation set accuracy
#
# epoch 249: 	 94.95% - train set accuracy
# 		 88.77% - validation set accuracy
#
# epoch 250: 	 94.85% - train set accuracy
# 		 88.74% - validation set accuracy
#
# epoch 251: 	 94.98% - train set accuracy
# 		 88.95% - validation set accuracy
#
# epoch 252: 	 94.92% - train set accuracy
# 		 88.72% - validation set accuracy
#
# epoch 253: 	 94.84% - train set accuracy
# 		 88.79% - validation set accuracy
#
# epoch 254: 	 94.99% - train set accuracy
# 		 88.69% - validation set accuracy
#
# epoch 255: 	 95.00% - train set accuracy
# 		 88.98% - validation set accuracy
#
# epoch 256: 	 94.89% - train set accuracy
# 		 88.46% - validation set accuracy
#
# epoch 257: 	 94.88% - train set accuracy
# 		 88.89% - validation set accuracy
#
# epoch 258: 	 94.94% - train set accuracy
# 		 88.79% - validation set accuracy
#
# epoch 259: 	 94.93% - train set accuracy
# 		 88.75% - validation set accuracy
#
# epoch 260: 	 95.04% - train set accuracy
# 		 88.74% - validation set accuracy
#
# epoch 261: 	 94.90% - train set accuracy
# 		 88.61% - validation set accuracy
#
# epoch 262: 	 94.95% - train set accuracy
# 		 88.92% - validation set accuracy
#
# epoch 263: 	 94.97% - train set accuracy
# 		 88.78% - validation set accuracy
#
# epoch 264: 	 95.03% - train set accuracy
# 		 88.68% - validation set accuracy
#
# epoch 265: 	 94.93% - train set accuracy
# 		 88.56% - validation set accuracy
#
# epoch 266: 	 94.95% - train set accuracy
# 		 88.74% - validation set accuracy
#
# epoch 267: 	 95.10% - train set accuracy
# 		 88.86% - validation set accuracy
#
# epoch 268: 	 94.89% - train set accuracy
# 		 88.71% - validation set accuracy
#
# epoch 269: 	 95.07% - train set accuracy
# 		 88.72% - validation set accuracy
#
# epoch 270: 	 94.88% - train set accuracy
# 		 88.85% - validation set accuracy
#
# epoch 271: 	 95.08% - train set accuracy
# 		 88.98% - validation set accuracy
#
# epoch 272: 	 95.05% - train set accuracy
# 		 88.78% - validation set accuracy
#
# epoch 273: 	 95.10% - train set accuracy
# 		 88.48% - validation set accuracy
#
# epoch 274: 	 94.89% - train set accuracy
# 		 88.91% - validation set accuracy
#
# epoch 275: 	 95.05% - train set accuracy
# 		 88.71% - validation set accuracy
#
# epoch 276: 	 95.03% - train set accuracy
# 		 88.75% - validation set accuracy
#
# epoch 277: 	 94.91% - train set accuracy
# 		 88.61% - validation set accuracy
#
# epoch 278: 	 95.01% - train set accuracy
# 		 88.72% - validation set accuracy
#
# epoch 279: 	 95.05% - train set accuracy
# 		 88.56% - validation set accuracy
#
# epoch 280: 	 95.03% - train set accuracy
# 		 88.45% - validation set accuracy
#
# epoch 281: 	 94.98% - train set accuracy
# 		 88.96% - validation set accuracy
#
# epoch 282: 	 94.95% - train set accuracy
# 		 88.76% - validation set accuracy
#
# epoch 283: 	 95.05% - train set accuracy
# 		 88.48% - validation set accuracy
#
# epoch 284: 	 95.03% - train set accuracy
# 		 88.85% - validation set accuracy
#
# epoch 285: 	 95.01% - train set accuracy
# 		 88.68% - validation set accuracy
#
# epoch 286: 	 95.02% - train set accuracy
# 		 88.79% - validation set accuracy
#
# epoch 287: 	 95.07% - train set accuracy
# 		 88.80% - validation set accuracy
#
# epoch 288: 	 95.06% - train set accuracy
# 		 88.72% - validation set accuracy
#
# epoch 289: 	 95.08% - train set accuracy
# 		 88.55% - validation set accuracy
#
# epoch 290: 	 95.08% - train set accuracy
# 		 88.79% - validation set accuracy
#
# epoch 291: 	 94.99% - train set accuracy
# 		 88.89% - validation set accuracy
#
# epoch 292: 	 95.16% - train set accuracy
# 		 88.92% - validation set accuracy
#
# epoch 293: 	 95.16% - train set accuracy
# 		 88.67% - validation set accuracy
#
# epoch 294: 	 94.91% - train set accuracy
# 		 88.86% - validation set accuracy
#
# epoch 295: 	 95.14% - train set accuracy
# 		 88.54% - validation set accuracy
#
# epoch 296: 	 95.12% - train set accuracy
# 		 88.81% - validation set accuracy
#
# epoch 297: 	 95.14% - train set accuracy
# 		 88.78% - validation set accuracy
#
# epoch 298: 	 95.04% - train set accuracy
# 		 88.83% - validation set accuracy
#
# epoch 299: 	 95.07% - train set accuracy
# 		 88.83% - validation set accuracy
#
# epoch 300: 	 95.16% - train set accuracy
# 		 88.61% - validation set accuracy
#
# Best result: 89.92%

# %% [markdown]
# Максимальная достигнутая точность на проверочной части датасета составляет **89.92%**

# %% [markdown]
# ### 1.4 Сохранение модели на диск

# %% [markdown]
# Обучение модели выполняется посредством функции `train` (см. раздел 1.3). Функция `train` использует глобальные переменные `validationAccToTrain` и `epochsForTraining`. Значение глобальной переменной `validationAccToTrain` соответствует точности (accuracy) на проверочной части датасета, при достижении которой и одновременно максимальной точности в ходе обучения, необходимо сохранить архитектуру и параметры модели на диск. Сохранение модели на диск выполняется посредством функции `net.export`, при этом создаются/перезаписываются два файла: **fashion-mnist-symbol.json**, содержащий информацию, определяющую архитектуру модели, и **fashion-mnist-<номер эпохи>.params**, содержащий параметры модели, полученные в ходе обучения и соответствующие эпохе <номер эпохи>. Значение глобальной переменной `epochsForTraining` соответствует количеству эпох, в течение которых необходимо проводить обучение.

# %% [markdown]
# ## Ссылки

# %% [markdown]
# 1. Официальный сайт mxnet: https://mxnet.apache.org/
