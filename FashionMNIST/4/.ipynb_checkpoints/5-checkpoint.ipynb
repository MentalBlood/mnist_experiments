# %% [markdown]
# # Отчет о создании и обучении на датасете Fashion MNIST модели CNN (гипотеза 4, реализация 1)

# %% [markdown]
# ## Содержание
#
# - Список терминов, специфичных для темы отчета
# - Введение
# - 1 Создание и обучение модели
#  - 1.1 Загрузка датасета
#  - 1.2 Создание модели
#  - 1.3 Обучение модели
#  - 1.4 Сохранение модели на диск
# - 2 Рекомендации по дальнейшему улучшению/развитию модели
# - Ссылки

# %% [markdown]
# ## Список терминов, специфичных для темы отчета
#
# См. раздел "Машинное обучение" документа "Словарь терминов, специфичных для выполняемых работ и изучаемых материалов в период с 25 сентября 2020 г. по 25 ноября 2020 г.".

# %% [markdown]
# ## Введение

# %% [markdown]
# В настоящем отчете приведен код, соответствующий созданию и обучению модели CNN на датасете Fashion MNIST, а также рекомендации по дальнейшему улучшению/развитию модели. Используемый язык программирования – Python. Для создания и обучения модели используются библиотеки MXNet и Gluon.

# %% [markdown]
# ## 1 Создание и обучение модели

# %% [markdown]
# Импортирование необходимых модулей и функций:

# %%
import mxnet as mx
from mxnet.optimizer import Adam
from mxnet import gluon, autograd
from mxnet.gluon import nn
from mxnet.gluon.data.vision import datasets, transforms

# %% [markdown]
# Установка вычислительного контекста (для использования при обучении видеокарты, если это возможно):

# %%
ctx = [mx.gpu() if mx.test_utils.list_gpus() else mx.cpu()]
print('context:', ctx)
# Out:
# context: [gpu(0)]

# %% [markdown]
# ### 1.1 Загрузка датасета

# %% [markdown]
# Загрузка датасета и установка размера батча равным 128:

# %%
batch_size = 128

mnist_train = datasets.FashionMNIST(train=True)
transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.13, 0.31)])
mnist_train = mnist_train.transform_first(transformer)
train_data = gluon.data.DataLoader(
    mnist_train, batch_size=batch_size, shuffle=True, num_workers=4)

mnist_valid = gluon.data.vision.FashionMNIST(train=False)
val_data = gluon.data.DataLoader(
    mnist_valid.transform_first(transformer),
    batch_size=batch_size, num_workers=4)

# %% [markdown]
# ### 1.2 Создание модели

# %% [markdown]
# Создание модели, состоящей из 4 слоев:
# 1. Сверточный слой с параметрами:
# 	- Количество каналов: 8
# 	- Размер ядра свертки: **5х5**
# 	- Функция активации: гиперболический тангенс
# 2. Слой пулинга с параметрами:
# 	- Размер ядра пулинга: 2х2
# 	- Шаг: 2
# 3. Полносвязный слой с параметрами:
# 	- Количество нейронов: 16
# 	- Функция активации: гиперболический тангенс
# 4. Полносвязный слой с параметрами:
# 	- Количество нейронов: 10
# 	- Функция активации: гиперболический тангенс

# %%
net = nn.HybridSequential()
with net.name_scope():
    net.add(nn.Conv2D   (channels=8, kernel_size=5, activation='tanh'))
    #                                            ^--- 4 -> 5
    net.add(nn.MaxPool2D(pool_size=2, strides=2))
    net.add(nn.Dense    (16, activation='tanh'))
    net.add(nn.Dense    (10, activation='tanh'))
net.hybridize()

# %% [markdown]
# ### 1.3 Обучение модели

# %% [markdown]
# Для инициализации сети используется метод Завьера (Xavier). В качестве функции потерь используется SCE (Softmax Cross-Entropy loss). В качестве оптимизатора используется Adam (Adaptive Moment Estimation – метод Адаптивной Оценки Моментов). Обучение производится на протижение 100 эпох.

# %%
epochsForTraining = 100
validationAccToTrain = 0.90

def test(ctx):
    metric = mx.metric.Accuracy()
    for data, label in val_data:
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        output = net(data)
        metric.update([label], [output])

    return metric.get()

def train(net, ctx):
    # Collect all parameters from net and its children, then initialize them.
    net.initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
    # Trainer is for updating parameters with gradient.
    trainer = gluon.Trainer(net.collect_params(), Adam())
    metric = mx.metric.Accuracy()
    loss = gluon.loss.SoftmaxCrossEntropyLoss()

    maxValidationAcc = 0
    for i in range(epochsForTraining):
        # reset data iterator and metric at begining of epoch.
        metric.reset()
        for j, (data, label) in enumerate(train_data):
            # Copy data to ctx if necessary
            data = data.as_in_context(ctx)
            label = label.as_in_context(ctx)
            # Start recording computation graph with record() section.
            # Recorded graphs can then be differentiated with backward.
            with autograd.record():
                output = net(data)
                L = loss(output, label)
                L.backward()
            # take a gradient step with batch_size equal to data.shape[0]
            trainer.step(data.shape[0])
            # update metric at last.
            metric.update([label], [output])

        name, acc = metric.get()
        name, validationAcc = test(ctx)
        epoch = i + 1
        print('epoch', ('{:2.0f}:').format(epoch), '\t', "{:.2f}%".format(acc * 100), '- train set accuracy'
              '\n\t\t', "{:.2f}%".format(validationAcc * 100), '- validation set accuracy')
        if validationAcc > maxValidationAcc:
            maxValidationAcc = validationAcc
            if validationAcc >= validationAccToTrain:
                net.export('exported/5/fashion_mnist', epoch=epoch)
                print('saved epoch', epoch)
        print()
    print('Best result: {:.2f}%'.format(maxValidationAcc * 100))

# %%
train(net, ctx[0])
# Out:
# epoch  1: 	 76.47% - train set accuracy
# 		 82.24% - validation set accuracy
#
# epoch  2: 	 84.52% - train set accuracy
# 		 85.15% - validation set accuracy
#
# epoch  3: 	 86.27% - train set accuracy
# 		 87.08% - validation set accuracy
#
# epoch  4: 	 87.47% - train set accuracy
# 		 87.83% - validation set accuracy
#
# epoch  5: 	 88.09% - train set accuracy
# 		 87.84% - validation set accuracy
#
# epoch  6: 	 88.44% - train set accuracy
# 		 88.57% - validation set accuracy
#
# epoch  7: 	 88.92% - train set accuracy
# 		 88.22% - validation set accuracy
#
# epoch  8: 	 89.25% - train set accuracy
# 		 88.57% - validation set accuracy
#
# epoch  9: 	 89.53% - train set accuracy
# 		 88.69% - validation set accuracy
#
# epoch 10: 	 89.60% - train set accuracy
# 		 89.15% - validation set accuracy
#
# epoch 11: 	 89.94% - train set accuracy
# 		 89.35% - validation set accuracy
#
# epoch 12: 	 90.14% - train set accuracy
# 		 89.48% - validation set accuracy
#
# epoch 13: 	 90.22% - train set accuracy
# 		 89.26% - validation set accuracy
#
# epoch 14: 	 90.47% - train set accuracy
# 		 89.08% - validation set accuracy
#
# epoch 15: 	 90.53% - train set accuracy
# 		 89.52% - validation set accuracy
#
# epoch 16: 	 90.67% - train set accuracy
# 		 89.07% - validation set accuracy
#
# epoch 17: 	 90.87% - train set accuracy
# 		 89.64% - validation set accuracy
#
# epoch 18: 	 90.89% - train set accuracy
# 		 89.90% - validation set accuracy
#
# epoch 19: 	 91.08% - train set accuracy
# 		 89.72% - validation set accuracy
#
# epoch 20: 	 91.01% - train set accuracy
# 		 89.61% - validation set accuracy
#
# epoch 21: 	 91.21% - train set accuracy
# 		 89.68% - validation set accuracy
#
# epoch 22: 	 91.22% - train set accuracy
# 		 89.44% - validation set accuracy
#
# epoch 23: 	 91.27% - train set accuracy
# 		 90.01% - validation set accuracy
# saved epoch 23
#
# epoch 24: 	 91.40% - train set accuracy
# 		 89.69% - validation set accuracy
#
# epoch 25: 	 91.42% - train set accuracy
# 		 89.83% - validation set accuracy
#
# epoch 26: 	 91.56% - train set accuracy
# 		 89.87% - validation set accuracy
#
# epoch 27: 	 91.63% - train set accuracy
# 		 89.72% - validation set accuracy
#
# epoch 28: 	 91.70% - train set accuracy
# 		 89.88% - validation set accuracy
#
# epoch 29: 	 91.64% - train set accuracy
# 		 89.80% - validation set accuracy
#
# epoch 30: 	 91.84% - train set accuracy
# 		 90.01% - validation set accuracy
#
# epoch 31: 	 91.86% - train set accuracy
# 		 89.76% - validation set accuracy
#
# epoch 32: 	 91.94% - train set accuracy
# 		 89.87% - validation set accuracy
#
# epoch 33: 	 91.89% - train set accuracy
# 		 90.06% - validation set accuracy
# saved epoch 33
#
# epoch 34: 	 91.97% - train set accuracy
# 		 89.20% - validation set accuracy
#
# epoch 35: 	 91.97% - train set accuracy
# 		 89.86% - validation set accuracy
#
# epoch 36: 	 92.08% - train set accuracy
# 		 89.58% - validation set accuracy
#
# epoch 37: 	 92.20% - train set accuracy
# 		 89.73% - validation set accuracy
#
# epoch 38: 	 92.24% - train set accuracy
# 		 89.92% - validation set accuracy
#
# epoch 39: 	 92.30% - train set accuracy
# 		 90.05% - validation set accuracy
#
# epoch 40: 	 92.18% - train set accuracy
# 		 89.59% - validation set accuracy
#
# epoch 41: 	 92.40% - train set accuracy
# 		 89.92% - validation set accuracy
#
# epoch 42: 	 92.36% - train set accuracy
# 		 90.01% - validation set accuracy
#
# epoch 43: 	 92.46% - train set accuracy
# 		 89.98% - validation set accuracy
#
# epoch 44: 	 92.43% - train set accuracy
# 		 90.03% - validation set accuracy
#
# epoch 45: 	 92.53% - train set accuracy
# 		 89.90% - validation set accuracy
#
# epoch 46: 	 92.55% - train set accuracy
# 		 89.89% - validation set accuracy
#
# epoch 47: 	 92.59% - train set accuracy
# 		 90.11% - validation set accuracy
# saved epoch 47
#
# epoch 48: 	 92.61% - train set accuracy
# 		 90.01% - validation set accuracy
#
# epoch 49: 	 92.59% - train set accuracy
# 		 90.24% - validation set accuracy
# saved epoch 49
#
# epoch 50: 	 92.73% - train set accuracy
# 		 89.63% - validation set accuracy
#
# epoch 51: 	 92.72% - train set accuracy
# 		 90.11% - validation set accuracy
#
# epoch 52: 	 92.67% - train set accuracy
# 		 89.94% - validation set accuracy
#
# epoch 53: 	 92.78% - train set accuracy
# 		 89.89% - validation set accuracy
#
# epoch 54: 	 92.72% - train set accuracy
# 		 90.07% - validation set accuracy
#
# epoch 55: 	 92.81% - train set accuracy
# 		 89.84% - validation set accuracy
#
# epoch 56: 	 92.82% - train set accuracy
# 		 89.45% - validation set accuracy
#
# epoch 57: 	 92.88% - train set accuracy
# 		 89.37% - validation set accuracy
#
# epoch 58: 	 92.88% - train set accuracy
# 		 89.94% - validation set accuracy
#
# epoch 59: 	 92.93% - train set accuracy
# 		 90.02% - validation set accuracy
#
# epoch 60: 	 92.98% - train set accuracy
# 		 89.94% - validation set accuracy
#
# epoch 61: 	 93.15% - train set accuracy
# 		 90.07% - validation set accuracy
#
# epoch 62: 	 92.86% - train set accuracy
# 		 89.79% - validation set accuracy
#
# epoch 63: 	 92.96% - train set accuracy
# 		 89.83% - validation set accuracy
#
# epoch 64: 	 92.97% - train set accuracy
# 		 89.78% - validation set accuracy
#
# epoch 65: 	 93.11% - train set accuracy
# 		 89.93% - validation set accuracy
#
# epoch 66: 	 93.21% - train set accuracy
# 		 89.67% - validation set accuracy
#
# epoch 67: 	 93.17% - train set accuracy
# 		 89.81% - validation set accuracy
#
# epoch 68: 	 93.06% - train set accuracy
# 		 89.54% - validation set accuracy
#
# epoch 69: 	 93.11% - train set accuracy
# 		 90.02% - validation set accuracy
#
# epoch 70: 	 93.16% - train set accuracy
# 		 90.02% - validation set accuracy
#
# epoch 71: 	 93.11% - train set accuracy
# 		 89.72% - validation set accuracy
#
# epoch 72: 	 93.32% - train set accuracy
# 		 89.76% - validation set accuracy
#
# epoch 73: 	 93.32% - train set accuracy
# 		 90.01% - validation set accuracy
#
# epoch 74: 	 93.19% - train set accuracy
# 		 89.70% - validation set accuracy
#
# epoch 75: 	 93.32% - train set accuracy
# 		 89.86% - validation set accuracy
#
# epoch 76: 	 93.31% - train set accuracy
# 		 89.90% - validation set accuracy
#
# epoch 77: 	 93.28% - train set accuracy
# 		 90.00% - validation set accuracy
#
# epoch 78: 	 93.45% - train set accuracy
# 		 89.88% - validation set accuracy
#
# epoch 79: 	 93.47% - train set accuracy
# 		 89.82% - validation set accuracy
#
# epoch 80: 	 93.43% - train set accuracy
# 		 89.37% - validation set accuracy
#
# epoch 81: 	 93.48% - train set accuracy
# 		 89.77% - validation set accuracy
#
# epoch 82: 	 93.46% - train set accuracy
# 		 89.85% - validation set accuracy
#
# epoch 83: 	 93.47% - train set accuracy
# 		 89.91% - validation set accuracy
#
# epoch 84: 	 93.43% - train set accuracy
# 		 89.61% - validation set accuracy
#
# epoch 85: 	 93.58% - train set accuracy
# 		 89.62% - validation set accuracy
#
# epoch 86: 	 93.51% - train set accuracy
# 		 89.85% - validation set accuracy
#
# epoch 87: 	 93.62% - train set accuracy
# 		 89.50% - validation set accuracy
#
# epoch 88: 	 93.53% - train set accuracy
# 		 89.83% - validation set accuracy
#
# epoch 89: 	 93.65% - train set accuracy
# 		 89.97% - validation set accuracy
#
# epoch 90: 	 93.65% - train set accuracy
# 		 89.82% - validation set accuracy
#
# epoch 91: 	 93.61% - train set accuracy
# 		 90.19% - validation set accuracy
#
# epoch 92: 	 93.71% - train set accuracy
# 		 89.94% - validation set accuracy
#
# epoch 93: 	 93.64% - train set accuracy
# 		 89.88% - validation set accuracy
#
# epoch 94: 	 93.62% - train set accuracy
# 		 89.86% - validation set accuracy
#
# epoch 95: 	 93.79% - train set accuracy
# 		 89.79% - validation set accuracy
#
# epoch 96: 	 93.73% - train set accuracy
# 		 89.98% - validation set accuracy
#
# epoch 97: 	 93.71% - train set accuracy
# 		 89.90% - validation set accuracy
#
# epoch 98: 	 93.78% - train set accuracy
# 		 89.62% - validation set accuracy
#
# epoch 99: 	 93.88% - train set accuracy
# 		 89.92% - validation set accuracy
#
# epoch 100: 	 93.94% - train set accuracy
# 		 89.82% - validation set accuracy
#
# Best result: 90.24%

# %% [markdown]
# Максимальная достигнутая точность на проверочной части датасета составляет **90.24%** после 39-ой эпохи. Соответствующая этой эпохе точность на тренировочном датасете составляет **91.97%**.

# %% [markdown]
# ### 1.4 Сохранение модели на диск

# %% [markdown]
# Обучение модели выполняется посредством функции `train` (см. раздел 1.3). Функция `train` использует глобальные переменные `validationAccToTrain` и `epochsForTraining`. Значение глобальной переменной `validationAccToTrain` соответствует точности (accuracy) на проверочной части датасета, при достижении которой и одновременно максимальной точности в ходе обучения, необходимо сохранить архитектуру и параметры модели на диск. Сохранение модели на диск выполняется посредством функции `net.export`, при этом создаются/перезаписываются два файла: **fashion-mnist-symbol.json**, содержащий информацию, определяющую архитектуру модели, и **fashion-mnist-<номер эпохи>.params**, содержащий параметры модели, полученные в ходе обучения и соответствующие эпохе <номер эпохи>. Значение глобальной переменной `epochsForTraining` соответствует количеству эпох, в течение которых необходимо проводить обучение.

# %% [markdown]
# ## Ссылки

# %% [markdown]
# 1. Официальный сайт mxnet: https://mxnet.apache.org/
