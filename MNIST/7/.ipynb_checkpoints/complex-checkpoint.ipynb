# %% [markdown]
# # Отчет о создании и обучении на датасете MNIST модели CNN (гипотеза 7)

# %% [markdown]
# ## Содержание
#
# - Список терминов, специфичных для темы отчета
# - Введение
# - 1 Создание и обучение модели
#  - 1.1 Загрузка датасета
#  - 1.2 Создание модели
#  - 1.3 Обучение модели
#  - 1.4 Сохранение модели на диск
# - 2 Рекомендации по дальнейшему улучшению/развитию модели
# - Ссылки

# %% [markdown]
# ## Список терминов, специфичных для темы отчета
#
# См. раздел "Машинное обучение" документа "Словарь терминов, специфичных для выполняемых работ и изучаемых материалов в период с 25 сентября 2020 г. по 25 ноября 2020 г.".

# %% [markdown]
# ## Введение

# %% [markdown]
# В настоящем отчете приведен код, соответствующий созданию и обучению модели CNN на датасете MNIST, а также рекомендации по дальнейшему улучшению/развитию модели. Используемый язык программирования – Python. Для создания и обучения модели используются библиотеки MXNet и Gluon.

# %% [markdown]
# ## 1 Создание и обучение модели

# %% [markdown]
# Импортирование необходимых модулей и функций:

# %%
import mxnet as mx
from mxnet.optimizer import Adam
from mxnet.gluon import nn
from mxnet import autograd as ag
from mxnet import gluon

# %% [markdown]
# Установка вычислительного контекста (для использования при обучении видеокарты, если это возможно):

# %%
ctx = [mx.gpu() if mx.test_utils.list_gpus() else mx.cpu()]
print('context:', ctx)
# Out:
# context: [gpu(0)]

# %% [markdown]
# ### 1.1 Загрузка датасета

# %% [markdown]
# Загрузка датасета и установка размера батча равным 200:

# %%
mnist = mx.test_utils.get_mnist()

batch_size = 200
train_data = mx.io.NDArrayIter(mnist['train_data'], mnist['train_label'], batch_size, shuffle=True)
val_data = mx.io.NDArrayIter(mnist['test_data'], mnist['test_label'], batch_size)

# %% [markdown]
# ### 1.2 Создание модели

# %% [markdown]
# Создание модели, состоящей из 12 слоев:
# 1. Сверточный слой с параметрами:
#     - Количество каналов: 64
#     - Размер ядра свертки: 3х3
#     - Функция активации: гиперболический тангенс
# 2. Сверточный слой с параметрами:
#     - Количество каналов: 64
#     - Размер ядра свертки: 3х3
#     - Функция активации: гиперболический тангенс
#     - Коэффициент dropout: 0.20
# 3. Слой побатчевой нормализации
# 4. Слой пулинга с параметрами:
#     - Размер ядра пулинга: 2х2
#     - Шаг: 2
# 5. Сверточный слой с параметрами:
#     - Количество каналов: 128
#     - Размер ядра свертки: 3х3
#     - Функция активации: гиперболический тангенс
# 6. Сверточный слой с параметрами:
#     - Количество каналов: 128
#     - Размер ядра свертки: 3х3
#     - Функция активации: гиперболический тангенс
#     - Коэффициент dropout: 0.25
# 7. Слой побатчевой нормализации
# 8. Слой пулинга с параметрами:
#     - Размер ядра пулинга: 2х2
#     - Шаг: 2
# 9. Сверточный слой с параметрами:
#     - Количество каналов: 256
#     - Размер ядра свертки: 3х3
#     - Функция активации: гиперболический тангенс
#     - Коэффициент dropout: 0.25
# 10. Слой побатчевой нормализации
# 11. Полносвязный слой с параметрами:
#     - Количество нейронов: 512
#     - Функция активации: гиперболический тангенс
# 12. Полносвязный слой с параметрами:
#     - Количество нейронов: 10
#     - Функция активации: гиперболический тангенс

# %%
def buildNet(net):
    with net.name_scope():
        net.add(nn.Conv2D(64, kernel_size=3, activation='tanh'))
        net.add(nn.Conv2D(64, kernel_size=3, activation='tanh'))
        net.add(nn.Dropout(0.20))
        net.add(nn.BatchNorm())
        
        net.add(nn.MaxPool2D(pool_size=2, strides=2))
        net.add(nn.Conv2D(128, kernel_size=3, activation='tanh'))
        net.add(nn.Conv2D(128, kernel_size=3, activation='tanh'))
        net.add(nn.Dropout(0.25))
        net.add(nn.BatchNorm())
        
        net.add(nn.MaxPool2D(pool_size=2, strides=2))
        net.add(nn.Conv2D(256, kernel_size=3, activation='tanh'))
        net.add(nn.Dropout(0.25))
        net.add(nn.BatchNorm())
        
        net.add(nn.Dense(512, activation='tanh'))
        net.add(nn.Dense(10, activation='tanh'))
        return net

# %% [markdown]
# ### 1.3 Обучение модели

# %% [markdown]
# Для инициализации сети используется метод Завьера (Xavier). В качестве функции потерь используется SCE (Softmax Cross-Entropy loss). В качестве оптимизатора используется градиентный спуск с инерцией. Темп обучения (learning rate) устанавливается равным 0.1. Обучение производится в течение 130 эпох.

# %%
# %%time

def getValidationAcc():
    # Use Accuracy as the evaluation metric.
    metric = mx.metric.Accuracy()
    # Reset the validation data iterator.
    val_data.reset()
    # Loop over the validation data iterator.
    for batch in val_data:
        # Splits validation data into multiple slices along batch_axis
        # and copy each slice into a context.
        data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
        # Splits validation label into multiple slices along batch_axis
        # and copy each slice into a context.
        label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
        outputs = []
        for x in data:
            outputs.append(net(x))
        # Updates internal evaluation
        metric.update(label, outputs)
    return metric.get()[1]

validationAccToTrain = 0.993
epochsToTrain = 150

def train(net):
    # Use Accuracy as the evaluation metric.
    metric = mx.metric.Accuracy()
    # Initialize the parameters with Xavier initializer
    net.collect_params().initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
    # Use cross entropy loss
    softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()
    # Use Adam optimizer
    trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': 0.1})
    validationAcc = None
    maxValidationAcc = 0

    for i in range(epochsToTrain):
        # Reset the train data iterator.
        train_data.reset()
        # Loop over the train data iterator.
        for batch in train_data:
            # Splits train data into multiple slices along batch_axis
            # and copy each slice into a context.
            data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
            # Splits train labels into multiple slices along batch_axis
            # and copy each slice into a context.
            label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
            outputs = []
            # Inside training scope
            with ag.record():
                for x, y in zip(data, label):
                    z = net(x)
                    # Computes softmax cross entropy loss.
                    loss = softmax_cross_entropy(z, y)
                    # Backpropogate the error for one iteration.
                    loss.backward()
                    outputs.append(z)
            # Updates internal evaluation
            metric.update(label, outputs)
            # Make one step of parameter update. Trainer needs to know the
            # batch size of data to normalize the gradient by 1/batch_size.
            trainer.step(batch.data[0].shape[0])
        # Gets the evaluation result.
        name, acc = metric.get()
        # Reset evaluation result to initial state.
        metric.reset()
        validationAcc = getValidationAcc()
        epoch = i + 1
        print('epoch', ('{:2.0f}:').format(epoch), '\t', "{:.2f}%".format(acc * 100), '- train set accuracy'
              '\n\t\t', "{:.2f}%".format(validationAcc * 100), '- validation set accuracy')
        if (validationAcc >= validationAccToTrain) and (validationAcc > maxValidationAcc):
            maxValidationAcc = validationAcc
            net.export('mnist', epoch=epoch)
            print('saved epoch', epoch)
        print()

net = buildNet(nn.HybridSequential())
net.hybridize()
train(net)
# Out:
# epoch  1: 	 94.99% - train set accuracy
# 		 97.53% - validation set accuracy
#
# epoch  2: 	 98.21% - train set accuracy
# 		 97.47% - validation set accuracy
#
# epoch  3: 	 98.61% - train set accuracy
# 		 98.80% - validation set accuracy
#
# epoch  4: 	 98.78% - train set accuracy
# 		 98.67% - validation set accuracy
#
# epoch  5: 	 98.99% - train set accuracy
# 		 98.84% - validation set accuracy
#
# epoch  6: 	 99.08% - train set accuracy
# 		 98.94% - validation set accuracy
#
# epoch  7: 	 99.14% - train set accuracy
# 		 99.16% - validation set accuracy
#
# epoch  8: 	 99.21% - train set accuracy
# 		 99.01% - validation set accuracy
#
# epoch  9: 	 99.28% - train set accuracy
# 		 99.09% - validation set accuracy
#
# epoch 10: 	 99.37% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 11: 	 99.35% - train set accuracy
# 		 99.09% - validation set accuracy
#
# epoch 12: 	 99.41% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 13: 	 99.48% - train set accuracy
# 		 99.24% - validation set accuracy
#
# epoch 14: 	 99.45% - train set accuracy
# 		 99.16% - validation set accuracy
#
# epoch 15: 	 99.53% - train set accuracy
# 		 99.14% - validation set accuracy
#
# epoch 16: 	 99.57% - train set accuracy
# 		 99.28% - validation set accuracy
#
# epoch 17: 	 99.53% - train set accuracy
# 		 99.28% - validation set accuracy
#
# epoch 18: 	 99.62% - train set accuracy
# 		 98.91% - validation set accuracy
#
# epoch 19: 	 99.59% - train set accuracy
# 		 99.33% - validation set accuracy
# saved epoch 19
#
# epoch 20: 	 99.62% - train set accuracy
# 		 99.21% - validation set accuracy
#
# epoch 21: 	 99.64% - train set accuracy
# 		 99.30% - validation set accuracy
#
# epoch 22: 	 99.64% - train set accuracy
# 		 99.16% - validation set accuracy
#
# epoch 23: 	 99.64% - train set accuracy
# 		 99.33% - validation set accuracy
#
# epoch 24: 	 99.66% - train set accuracy
# 		 99.35% - validation set accuracy
# saved epoch 24
#
# epoch 25: 	 99.72% - train set accuracy
# 		 99.25% - validation set accuracy
#
# epoch 26: 	 99.70% - train set accuracy
# 		 99.36% - validation set accuracy
# saved epoch 26
#
# epoch 27: 	 99.72% - train set accuracy
# 		 99.26% - validation set accuracy
#
# epoch 28: 	 99.73% - train set accuracy
# 		 99.24% - validation set accuracy
#
# epoch 29: 	 99.72% - train set accuracy
# 		 99.31% - validation set accuracy
#
# epoch 30: 	 99.74% - train set accuracy
# 		 99.28% - validation set accuracy
#
# epoch 31: 	 99.77% - train set accuracy
# 		 99.30% - validation set accuracy
#
# epoch 32: 	 99.77% - train set accuracy
# 		 99.29% - validation set accuracy
#
# epoch 33: 	 99.79% - train set accuracy
# 		 99.42% - validation set accuracy
# saved epoch 33
#
# epoch 34: 	 99.76% - train set accuracy
# 		 99.37% - validation set accuracy
#
# epoch 35: 	 99.78% - train set accuracy
# 		 99.29% - validation set accuracy
#
# epoch 36: 	 99.81% - train set accuracy
# 		 99.30% - validation set accuracy
#
# epoch 37: 	 99.82% - train set accuracy
# 		 99.37% - validation set accuracy
#
# epoch 38: 	 99.81% - train set accuracy
# 		 99.25% - validation set accuracy
#
# epoch 39: 	 99.83% - train set accuracy
# 		 99.37% - validation set accuracy
#
# epoch 40: 	 99.81% - train set accuracy
# 		 99.33% - validation set accuracy
#
# epoch 41: 	 99.83% - train set accuracy
# 		 99.28% - validation set accuracy
#
# epoch 42: 	 99.83% - train set accuracy
# 		 99.35% - validation set accuracy
#
# epoch 43: 	 99.82% - train set accuracy
# 		 99.27% - validation set accuracy
#
# epoch 44: 	 99.86% - train set accuracy
# 		 99.29% - validation set accuracy
#
# epoch 45: 	 99.84% - train set accuracy
# 		 99.34% - validation set accuracy
#
# epoch 46: 	 99.86% - train set accuracy
# 		 99.31% - validation set accuracy
#
# epoch 47: 	 99.85% - train set accuracy
# 		 99.12% - validation set accuracy
#
# epoch 48: 	 99.86% - train set accuracy
# 		 99.27% - validation set accuracy
#
# epoch 49: 	 99.88% - train set accuracy
# 		 99.28% - validation set accuracy
#
# epoch 50: 	 99.88% - train set accuracy
# 		 99.29% - validation set accuracy
#
# epoch 51: 	 99.89% - train set accuracy
# 		 99.35% - validation set accuracy
#
# epoch 52: 	 99.88% - train set accuracy
# 		 99.28% - validation set accuracy
#
# epoch 53: 	 99.88% - train set accuracy
# 		 99.24% - validation set accuracy
#
# epoch 54: 	 99.91% - train set accuracy
# 		 99.22% - validation set accuracy
#
# epoch 55: 	 99.89% - train set accuracy
# 		 99.23% - validation set accuracy
#
# epoch 56: 	 99.88% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 57: 	 99.89% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 58: 	 99.90% - train set accuracy
# 		 99.10% - validation set accuracy
#
# epoch 59: 	 99.91% - train set accuracy
# 		 99.36% - validation set accuracy
#
# epoch 60: 	 99.90% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 61: 	 99.91% - train set accuracy
# 		 99.39% - validation set accuracy
#
# epoch 62: 	 99.92% - train set accuracy
# 		 99.33% - validation set accuracy
#
# epoch 63: 	 99.90% - train set accuracy
# 		 99.43% - validation set accuracy
# saved epoch 63
#
# epoch 64: 	 99.91% - train set accuracy
# 		 99.36% - validation set accuracy
#
# epoch 65: 	 99.91% - train set accuracy
# 		 99.34% - validation set accuracy
#
# epoch 66: 	 99.91% - train set accuracy
# 		 99.30% - validation set accuracy
#
# epoch 67: 	 99.91% - train set accuracy
# 		 99.30% - validation set accuracy
#
# epoch 68: 	 99.93% - train set accuracy
# 		 99.37% - validation set accuracy
#
# epoch 69: 	 99.92% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 70: 	 99.92% - train set accuracy
# 		 99.36% - validation set accuracy
#
# epoch 71: 	 99.91% - train set accuracy
# 		 99.38% - validation set accuracy
#
# epoch 72: 	 99.93% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 73: 	 99.93% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 74: 	 99.91% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 75: 	 99.94% - train set accuracy
# 		 99.43% - validation set accuracy
#
# epoch 76: 	 99.94% - train set accuracy
# 		 99.45% - validation set accuracy
# saved epoch 76
#
# epoch 77: 	 99.93% - train set accuracy
# 		 99.38% - validation set accuracy
#
# epoch 78: 	 99.94% - train set accuracy
# 		 99.42% - validation set accuracy
#
# epoch 79: 	 99.94% - train set accuracy
# 		 99.48% - validation set accuracy
# saved epoch 79
#
# epoch 80: 	 99.93% - train set accuracy
# 		 99.46% - validation set accuracy
#
# epoch 81: 	 99.95% - train set accuracy
# 		 99.44% - validation set accuracy
#
# epoch 82: 	 99.94% - train set accuracy
# 		 99.44% - validation set accuracy
#
# epoch 83: 	 99.94% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 84: 	 99.95% - train set accuracy
# 		 99.38% - validation set accuracy
#
# epoch 85: 	 99.94% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 86: 	 99.95% - train set accuracy
# 		 99.45% - validation set accuracy
#
# epoch 87: 	 99.95% - train set accuracy
# 		 99.45% - validation set accuracy
#
# epoch 88: 	 99.96% - train set accuracy
# 		 99.37% - validation set accuracy
#
# epoch 89: 	 99.95% - train set accuracy
# 		 99.47% - validation set accuracy
#
# epoch 90: 	 99.95% - train set accuracy
# 		 99.42% - validation set accuracy
#
# epoch 91: 	 99.95% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 92: 	 99.95% - train set accuracy
# 		 99.31% - validation set accuracy
#
# epoch 93: 	 99.94% - train set accuracy
# 		 99.39% - validation set accuracy
#
# epoch 94: 	 99.94% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 95: 	 99.95% - train set accuracy
# 		 99.44% - validation set accuracy
#
# epoch 96: 	 99.95% - train set accuracy
# 		 99.39% - validation set accuracy
#
# epoch 97: 	 99.96% - train set accuracy
# 		 99.35% - validation set accuracy
#
# epoch 98: 	 99.95% - train set accuracy
# 		 99.34% - validation set accuracy
#
# epoch 99: 	 99.96% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 100: 	 99.97% - train set accuracy
# 		 99.45% - validation set accuracy
#
# epoch 101: 	 99.95% - train set accuracy
# 		 99.30% - validation set accuracy
#
# epoch 102: 	 99.96% - train set accuracy
# 		 99.42% - validation set accuracy
#
# epoch 103: 	 99.96% - train set accuracy
# 		 99.44% - validation set accuracy
#
# epoch 104: 	 99.96% - train set accuracy
# 		 99.45% - validation set accuracy
#
# epoch 105: 	 99.94% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 106: 	 99.96% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 107: 	 99.95% - train set accuracy
# 		 99.31% - validation set accuracy
#
# epoch 108: 	 99.96% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 109: 	 99.97% - train set accuracy
# 		 99.42% - validation set accuracy
#
# epoch 110: 	 99.97% - train set accuracy
# 		 99.37% - validation set accuracy
#
# epoch 111: 	 99.96% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 112: 	 99.96% - train set accuracy
# 		 99.31% - validation set accuracy
#
# epoch 113: 	 99.96% - train set accuracy
# 		 99.30% - validation set accuracy
#
# epoch 114: 	 99.97% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 115: 	 99.97% - train set accuracy
# 		 99.37% - validation set accuracy
#
# epoch 116: 	 99.96% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 117: 	 99.96% - train set accuracy
# 		 99.37% - validation set accuracy
#
# epoch 118: 	 99.97% - train set accuracy
# 		 99.43% - validation set accuracy
#
# epoch 119: 	 99.96% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 120: 	 99.96% - train set accuracy
# 		 99.50% - validation set accuracy
# saved epoch 120
#
# epoch 121: 	 99.97% - train set accuracy
# 		 99.45% - validation set accuracy
#
# epoch 122: 	 99.96% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 123: 	 99.97% - train set accuracy
# 		 99.41% - validation set accuracy
#
# epoch 124: 	 99.97% - train set accuracy
# 		 99.37% - validation set accuracy
#
# epoch 125: 	 99.97% - train set accuracy
# 		 99.42% - validation set accuracy
#
# epoch 126: 	 99.97% - train set accuracy
# 		 99.34% - validation set accuracy
#
# epoch 127: 	 99.97% - train set accuracy
# 		 99.32% - validation set accuracy
#
# epoch 128: 	 99.98% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 129: 	 99.97% - train set accuracy
# 		 99.40% - validation set accuracy
#
# epoch 130: 	 99.97% - train set accuracy
# 		 99.38% - validation set accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in train(net)
#
# ~/.local/lib/python3.6/site-packages/mxnet/metric.py in update(self, labels, preds)
#     492             if pred_label.shape != label.shape:
#     493                 pred_label = ndarray.argmax(pred_label, axis=self.axis)
# --> 494             pred_label = pred_label.asnumpy().astype('int32')
#     495             label = label.asnumpy().astype('int32')
#     496             # flatten before checking shapes to avoid shape miss match
#
# ~/.local/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in asnumpy(self)
#    2533             self.handle,
#    2534             data.ctypes.data_as(ctypes.c_void_p),
# -> 2535             ctypes.c_size_t(data.size)))
#    2536         return data
#    2537
#
# KeyboardInterrupt:

# %% [markdown]
# Максимальная достигнутая точность на проверочной части датасета составляет **99.50%** после 120-ой эпохи. Соответствующая этой эпохе точность на тренировочном датасете составляет **99.96%**.

# %% [markdown]
# ### 1.4 Сохранение модели на диск

# %% [markdown]
# Обучение модели выполняется посредством функции `train` (см. раздел 1.3). Функция `train` использует глобальные переменные `validationAccToTrain` и `epochsToTrain`. Значение глобальной переменной `validationAccToTrain` соответствует точности (accuracy) на проверочной части датасета, при достижении которой и одновременно максимальной точности в ходе обучения, необходимо сохранить архитектуру и параметры модели на диск. Сохранение модели на диск выполняется посредством функции `net.export`, при этом создаются/перезаписываются два файла: **mnist-symbol.json**, содержащий информацию, определяющую архитектуру модели, и **mnist-<номер эпохи>.params**, содержащий параметры модели, полученные в ходе обучения и соответствующие эпохе <номер эпохи>. Значение глобальной переменной `epochsToTrain` соответствует количеству эпох, в течение которых необходимо проводить обучение.

# %% [markdown]
# ## Ссылки

# %% [markdown]
# 1. Официальный сайт mxnet: https://mxnet.apache.org/
