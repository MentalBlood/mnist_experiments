# %% [markdown]
# # Отчет о создании и обучении на датасете MNIST модели CNN (гипотеза 6, реализация 2)

# %% [markdown]
# ## Содержание
#
# - Список терминов, специфичных для темы отчета
# - Введение
# - 1 Создание и обучение модели
#  - 1.1 Загрузка датасета
#  - 1.2 Создание модели
#  - 1.3 Обучение модели
#  - 1.4 Сохранение модели на диск
# - 2 Рекомендации по дальнейшему улучшению/развитию модели
# - Ссылки

# %% [markdown]
# ## Список терминов, специфичных для темы отчета
#
# См. раздел "Машинное обучение" документа "Словарь терминов, специфичных для выполняемых работ и изучаемых материалов в период с 25 сентября 2020 г. по 25 ноября 2020 г.".

# %% [markdown]
# ## Введение

# %% [markdown]
# В настоящем отчете приведен код, соответствующий созданию и обучению модели CNN на датасете MNIST, а также рекомендации по дальнейшему улучшению/развитию модели. Используемый язык программирования – Python. Для создания и обучения модели используются библиотеки MXNet и Gluon.

# %% [markdown]
# ## 1 Создание и обучение модели

# %% [markdown]
# Импортирование необходимых модулей и функций:

# %%
import mxnet as mx
from mxnet.optimizer import Adam
from mxnet.gluon import nn
from mxnet import autograd as ag
from mxnet import gluon

# %% [markdown]
# Установка вычислительного контекста (для использования при обучении видеокарты, если это возможно):

# %%
ctx = [mx.gpu() if mx.test_utils.list_gpus() else mx.cpu()]
print('context:', ctx)
# Out:
# context: [gpu(0)]

# %% [markdown]
# ### 1.1 Загрузка датасета

# %% [markdown]
# Загрузка датасета и установка размера батча равным 200:

# %%
mnist = mx.test_utils.get_mnist()

batch_size = 200
train_data = mx.io.NDArrayIter(mnist['train_data'], mnist['train_label'], batch_size, shuffle=True)
val_data = mx.io.NDArrayIter(mnist['test_data'], mnist['test_label'], batch_size)

# %% [markdown]
# ### 1.2 Создание модели

# %% [markdown]
# Создание модели, состоящей из 6 слоев:
# 1. Сверточный слой с параметрами:
# 	- Количество каналов: 10
# 	- Размер ядра свертки: 5х5
# 	- Функция активации: гиперболический тангенс
# 2. Слой пулинга с параметрами:
# 	- Размер ядра пулинга: 2х2
# 	- Шаг: 2
# 3. Сверточный слой
# 	- Количество каналов: 25
# 	- Размер ядра свертки: 5х5
# 	- Функция активации: гиперболический тангенс
# 4. Слой пулинга с параметрами:
# 	- Размер ядра пулинга: 2х2
# 	- Шаг: 2
# 5. Полносвязный слой с параметрами:
# 	- Количество нейронов: 20
# 	- Функция активации: гиперболический тангенс
# 6. Полносвязный слой с параметрами:
# 	- Количество нейронов: 10
# 	- Функция активации: гиперболический тангенс

# %%
net = nn.HybridSequential()
with net.name_scope():
    net.add(nn.Conv2D(10, kernel_size=5, activation='tanh'))
    net.add(nn.MaxPool2D(pool_size=2, strides=2))
    net.add(nn.Conv2D(25, kernel_size=5, activation='tanh'))
    net.add(nn.MaxPool2D(pool_size=2, strides=2))
    net.add(nn.Dense(20, activation='tanh'))
    net.add(nn.Dense(10, activation='tanh'))
net.hybridize()

# %% [markdown]
# ### 1.3 Обучение модели

# %% [markdown]
# Для инициализации сети используется метод Завьера (Xavier). В качестве функции потерь используется SCE (Softmax Cross-Entropy loss). В качестве оптимизатора используется градиентный спуск с инерцией. Темп обучения (learning rate) устанавливается равным 0.6. Обучение производится в течение **100** эпох.

# %%
# %%time

def getValidationAcc():
    # Use Accuracy as the evaluation metric.
    metric = mx.metric.Accuracy()
    # Reset the validation data iterator.
    val_data.reset()
    # Loop over the validation data iterator.
    for batch in val_data:
        # Splits validation data into multiple slices along batch_axis
        # and copy each slice into a context.
        data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
        # Splits validation label into multiple slices along batch_axis
        # and copy each slice into a context.
        label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
        outputs = []
        for x in data:
            outputs.append(net(x))
        # Updates internal evaluation
        metric.update(label, outputs)
    return metric.get()[1]

validationAccToTrain = 0.99
epochsToTrain = 100
#               ^^--- 40 -> 100

def train(net):
    # Use Accuracy as the evaluation metric.
    metric = mx.metric.Accuracy()
    # Initialize the parameters with Xavier initializer
    net.collect_params().initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
    # Use cross entropy loss
    softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()
    # Use Adam optimizer
    trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': 0.6})
    validationAcc = None
    maxValidationAcc = 0

    for i in range(epochsToTrain):
        # Reset the train data iterator.
        train_data.reset()
        # Loop over the train data iterator.
        for batch in train_data:
            # Splits train data into multiple slices along batch_axis
            # and copy each slice into a context.
            data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
            # Splits train labels into multiple slices along batch_axis
            # and copy each slice into a context.
            label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
            outputs = []
            # Inside training scope
            with ag.record():
                for x, y in zip(data, label):
                    z = net(x)
                    # Computes softmax cross entropy loss.
                    loss = softmax_cross_entropy(z, y)
                    # Backpropogate the error for one iteration.
                    loss.backward()
                    outputs.append(z)
            # Updates internal evaluation
            metric.update(label, outputs)
            # Make one step of parameter update. Trainer needs to know the
            # batch size of data to normalize the gradient by 1/batch_size.
            trainer.step(batch.data[0].shape[0])
        # Gets the evaluation result.
        name, acc = metric.get()
        # Reset evaluation result to initial state.
        metric.reset()
        validationAcc = getValidationAcc()
        epoch = i + 1
        print('epoch', ('{:2.0f}:').format(epoch), '\t', "{:.2f}%".format(acc * 100), '- train set accuracy'
              '\n\t\t', "{:.2f}%".format(validationAcc * 100), '- validation set accuracy')
        if validationAcc > maxValidationAcc:
            maxValidationAcc = validationAcc
            if validationAcc >= validationAccToTrain:
                net.export('exported/100/mnist', epoch=epoch)
                print('saved epoch', epoch)
        print()
    print('Best result: {:.2f}%'.format(maxValidationAcc * 100))

train(net)
# Out:
# epoch  1: 	 91.75% - train set accuracy
# 		 95.81% - validation set accuracy
#
# epoch  2: 	 97.61% - train set accuracy
# 		 98.27% - validation set accuracy
#
# epoch  3: 	 98.33% - train set accuracy
# 		 98.50% - validation set accuracy
#
# epoch  4: 	 98.61% - train set accuracy
# 		 98.64% - validation set accuracy
#
# epoch  5: 	 98.88% - train set accuracy
# 		 98.56% - validation set accuracy
#
# epoch  6: 	 98.98% - train set accuracy
# 		 98.90% - validation set accuracy
#
# epoch  7: 	 99.08% - train set accuracy
# 		 98.91% - validation set accuracy
#
# epoch  8: 	 99.24% - train set accuracy
# 		 98.76% - validation set accuracy
#
# epoch  9: 	 99.30% - train set accuracy
# 		 98.85% - validation set accuracy
#
# epoch 10: 	 99.37% - train set accuracy
# 		 98.94% - validation set accuracy
#
# epoch 11: 	 99.44% - train set accuracy
# 		 99.03% - validation set accuracy
# saved epoch 11
#
# epoch 12: 	 99.48% - train set accuracy
# 		 98.91% - validation set accuracy
#
# epoch 13: 	 99.53% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 14: 	 99.56% - train set accuracy
# 		 99.04% - validation set accuracy
# saved epoch 14
#
# epoch 15: 	 99.61% - train set accuracy
# 		 98.98% - validation set accuracy
#
# epoch 16: 	 99.62% - train set accuracy
# 		 98.93% - validation set accuracy
#
# epoch 17: 	 99.65% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 18: 	 99.69% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 19: 	 99.71% - train set accuracy
# 		 98.93% - validation set accuracy
#
# epoch 20: 	 99.72% - train set accuracy
# 		 99.01% - validation set accuracy
#
# epoch 21: 	 99.76% - train set accuracy
# 		 99.00% - validation set accuracy
#
# epoch 22: 	 99.77% - train set accuracy
# 		 98.98% - validation set accuracy
#
# epoch 23: 	 99.77% - train set accuracy
# 		 98.97% - validation set accuracy
#
# epoch 24: 	 99.78% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 25: 	 99.79% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 26: 	 99.80% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 27: 	 99.80% - train set accuracy
# 		 99.05% - validation set accuracy
# saved epoch 27
#
# epoch 28: 	 99.82% - train set accuracy
# 		 98.99% - validation set accuracy
#
# epoch 29: 	 99.81% - train set accuracy
# 		 99.08% - validation set accuracy
# saved epoch 29
#
# epoch 30: 	 99.82% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 31: 	 99.83% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 32: 	 99.84% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 33: 	 99.84% - train set accuracy
# 		 99.01% - validation set accuracy
#
# epoch 34: 	 99.84% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 35: 	 99.84% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 36: 	 99.85% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 37: 	 99.85% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 38: 	 99.86% - train set accuracy
# 		 98.99% - validation set accuracy
#
# epoch 39: 	 99.85% - train set accuracy
# 		 99.00% - validation set accuracy
#
# epoch 40: 	 99.86% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 41: 	 99.86% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 42: 	 99.86% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 43: 	 99.86% - train set accuracy
# 		 98.99% - validation set accuracy
#
# epoch 44: 	 99.86% - train set accuracy
# 		 99.09% - validation set accuracy
# saved epoch 44
#
# epoch 45: 	 99.86% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 46: 	 99.87% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 47: 	 99.87% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 48: 	 99.87% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 49: 	 99.87% - train set accuracy
# 		 99.01% - validation set accuracy
#
# epoch 50: 	 99.88% - train set accuracy
# 		 99.08% - validation set accuracy
#
# epoch 51: 	 99.87% - train set accuracy
# 		 98.98% - validation set accuracy
#
# epoch 52: 	 99.87% - train set accuracy
# 		 99.01% - validation set accuracy
#
# epoch 53: 	 99.88% - train set accuracy
# 		 99.07% - validation set accuracy
#
# epoch 54: 	 99.88% - train set accuracy
# 		 99.06% - validation set accuracy
#
# epoch 55: 	 99.88% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 56: 	 99.88% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 57: 	 99.88% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 58: 	 99.88% - train set accuracy
# 		 99.07% - validation set accuracy
#
# epoch 59: 	 99.88% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 60: 	 99.88% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 61: 	 99.88% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 62: 	 99.88% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 63: 	 99.88% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 64: 	 99.89% - train set accuracy
# 		 99.06% - validation set accuracy
#
# epoch 65: 	 99.88% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 66: 	 99.89% - train set accuracy
# 		 99.07% - validation set accuracy
#
# epoch 67: 	 99.88% - train set accuracy
# 		 99.08% - validation set accuracy
#
# epoch 68: 	 99.89% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 69: 	 99.88% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 70: 	 99.89% - train set accuracy
# 		 99.01% - validation set accuracy
#
# epoch 71: 	 99.89% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 72: 	 99.89% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 73: 	 99.89% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 74: 	 99.89% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 75: 	 99.89% - train set accuracy
# 		 99.06% - validation set accuracy
#
# epoch 76: 	 99.89% - train set accuracy
# 		 99.07% - validation set accuracy
#
# epoch 77: 	 99.90% - train set accuracy
# 		 99.07% - validation set accuracy
#
# epoch 78: 	 99.90% - train set accuracy
# 		 99.07% - validation set accuracy
#
# epoch 79: 	 99.90% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 80: 	 99.90% - train set accuracy
# 		 99.06% - validation set accuracy
#
# epoch 81: 	 99.90% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 82: 	 99.90% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 83: 	 99.89% - train set accuracy
# 		 99.06% - validation set accuracy
#
# epoch 84: 	 99.90% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 85: 	 99.90% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 86: 	 99.90% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 87: 	 99.90% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 88: 	 99.90% - train set accuracy
# 		 99.02% - validation set accuracy
#
# epoch 89: 	 99.90% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 90: 	 99.90% - train set accuracy
# 		 99.07% - validation set accuracy
#
# epoch 91: 	 99.90% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 92: 	 99.90% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 93: 	 99.90% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 94: 	 99.90% - train set accuracy
# 		 99.03% - validation set accuracy
#
# epoch 95: 	 99.90% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 96: 	 99.90% - train set accuracy
# 		 99.06% - validation set accuracy
#
# epoch 97: 	 99.90% - train set accuracy
# 		 99.04% - validation set accuracy
#
# epoch 98: 	 99.90% - train set accuracy
# 		 99.05% - validation set accuracy
#
# epoch 99: 	 99.90% - train set accuracy
# 		 99.06% - validation set accuracy
#
# epoch 100: 	 99.90% - train set accuracy
# 		 99.02% - validation set accuracy
#
# Best result: 99.09%
# CPU times: user 1min 45s, sys: 15.7 s, total: 2min 1s
# Wall time: 1min 21s

# %% [markdown]
# Максимальная достигнутая точность на проверочной части датасета составляет **99.09%**

# %% [markdown]
# ### 1.4 Сохранение модели на диск

# %% [markdown]
# Обучение модели выполняется посредством функции `train` (см. раздел 1.3). Функция `train` использует глобальные переменные `validationAccToTrain` и `epochsToTrain`. Значение глобальной переменной `validationAccToTrain` соответствует точности (accuracy) на проверочной части датасета, при достижении которой и одновременно максимальной точности в ходе обучения, необходимо сохранить архитектуру и параметры модели на диск. Сохранение модели на диск выполняется посредством функции `net.export`, при этом создаются/перезаписываются два файла: **mnist-symbol.json**, содержащий информацию, определяющую архитектуру модели, и **mnist-<номер эпохи>.params**, содержащий параметры модели, полученные в ходе обучения и соответствующие эпохе <номер эпохи>. Значение глобальной переменной `epochsToTrain` соответствует количеству эпох, в течение которых необходимо проводить обучение.

# %% [markdown]
# ## Ссылки

# %% [markdown]
# 1. Официальный сайт mxnet: https://mxnet.apache.org/
